# %%
# !pip install dm_control
# !pip install pink-noise-rl
# !pip install wandb
# Out:
# Collecting dm_control
#   Downloading dm_control-1.0.16-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: absl-py>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from dm_control) (1.4.0)
# Collecting dm-env (from dm_control)
#   Downloading dm_env-1.6-py3-none-any.whl (26 kB)
# Requirement already satisfied: dm-tree!=0.1.2 in /opt/conda/lib/python3.10/site-packages (from dm_control) (0.1.8)
# Collecting glfw (from dm_control)
#   Downloading glfw-2.6.5-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting labmaze (from dm_control)
#   Downloading labmaze-1.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 53.9 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from dm_control) (5.1.0)
# Collecting mujoco>=3.1.1 (from dm_control)
#   Downloading mujoco-3.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from dm_control) (1.24.4)
# Requirement already satisfied: protobuf>=3.19.4 in /opt/conda/lib/python3.10/site-packages (from dm_control) (3.20.3)
# Collecting pyopengl>=3.1.4 (from dm_control)
#   Downloading PyOpenGL-3.1.7-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pyparsing>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from dm_control) (3.1.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from dm_control) (2.31.0)
# Requirement already satisfied: setuptools!=50.0.0 in /opt/conda/lib/python3.10/site-packages (from dm_control) (69.0.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from dm_control) (1.11.4)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from dm_control) (4.66.1)
# Requirement already satisfied: etils[epath] in /opt/conda/lib/python3.10/site-packages (from mujoco>=3.1.1->dm_control) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->dm_control) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->dm_control) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->dm_control) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->dm_control) (2023.11.17)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from etils[epath]->mujoco>=3.1.1->dm_control) (2023.12.2)
# Requirement already satisfied: importlib_resources in /opt/conda/lib/python3.10/site-packages (from etils[epath]->mujoco>=3.1.1->dm_control) (6.1.1)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.10/site-packages (from etils[epath]->mujoco>=3.1.1->dm_control) (4.9.0)
# Requirement already satisfied: zipp in /opt/conda/lib/python3.10/site-packages (from etils[epath]->mujoco>=3.1.1->dm_control) (3.17.0)
# Downloading dm_control-1.0.16-py3-none-any.whl (55.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 MB 30.4 MB/s eta 0:00:00
# Downloading mujoco-3.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 88.7 MB/s eta 0:00:00
# Downloading PyOpenGL-3.1.7-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 66.7 MB/s eta 0:00:00
# Downloading glfw-2.6.5-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 kB 14.2 MB/s eta 0:00:00
# Installing collected packages: pyopengl, glfw, labmaze, dm-env, mujoco, dm_control
# Successfully installed dm-env-1.6 dm_control-1.0.16 glfw-2.6.5 labmaze-1.0.6 mujoco-3.1.2 pyopengl-3.1.7
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.16.2)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.41)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (1.39.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.1)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (69.0.3)
# Requirement already satisfied: appdirs>=1.4.3 in /opt/conda/lib/python3.10/site-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2023.11.17)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.1)

# %%
import torch as th
device = th.device("cuda" if th.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
import gym
from gym import spaces

from dm_control import suite
from dm_env import specs


def convert_dm_control_to_gym_space(dm_control_space):
    r"""Convert dm_control space to gym space. """
    if isinstance(dm_control_space, specs.BoundedArray):
        space = spaces.Box(low=dm_control_space.minimum, 
                           high=dm_control_space.maximum, 
                           dtype=dm_control_space.dtype)
        assert space.shape == dm_control_space.shape
        return space
    elif isinstance(dm_control_space, specs.Array) and not isinstance(dm_control_space, specs.BoundedArray):
        space = spaces.Box(low=-float('inf'), 
                           high=float('inf'), 
                           shape=dm_control_space.shape, 
                           dtype=dm_control_space.dtype)
        return space
    elif isinstance(dm_control_space, dict):
        space = spaces.Dict({key: convert_dm_control_to_gym_space(value)
                             for key, value in dm_control_space.items()})
        return space


class DMSuiteEnv(gym.Env):
    def __init__(self, domain_name, task_name, task_kwargs=None, environment_kwargs=None, visualize_reward=False):
        self.env = suite.load(domain_name, 
                              task_name, 
                              task_kwargs=task_kwargs, 
                              environment_kwargs=environment_kwargs, 
                              visualize_reward=visualize_reward)
        self.metadata = {'render.modes': ['human', 'rgb_array'],
                         'video.frames_per_second': round(1.0/self.env.control_timestep())}
        print(self.env.observation_spec())
        self.observation_space = convert_dm_control_to_gym_space(self.env.observation_spec())
        print(self.observation_space)
        print("________________________")
        print(self.env.action_spec())
        self.action_space = convert_dm_control_to_gym_space(self.env.action_spec())
        print(self.action_space)
        self.viewer = None
    
    def seed(self, seed):
        return self.env.task.random.seed(seed)
    
    def step(self, action):
        timestep = self.env.step(action)
        observation = timestep.observation
        reward = timestep.reward
        done = timestep.last()
        info = {}
        truncated = False
        return observation, reward, done, info
    
    def reset(self):
        timestep = self.env.reset()
        return timestep.observation
    
    def render(self, mode='human', **kwargs):
        if 'camera_id' not in kwargs:
            kwargs['camera_id'] = 0  # Tracking camera
        use_opencv_renderer = kwargs.pop('use_opencv_renderer', False)
        
        img = self.env.physics.render(**kwargs)
        if mode == 'rgb_array':
            return img
        elif mode == 'human':
            if self.viewer is None:
                if not use_opencv_renderer:
                    from gym.envs.classic_control import rendering
                    self.viewer = rendering.SimpleImageViewer(maxwidth=1024)
                else:
                    from . import OpenCVImageViewer
                    self.viewer = OpenCVImageViewer()
            self.viewer.imshow(img)
            return self.viewer.isopen
        else:
            raise NotImplementedError

    def close(self):
        if self.viewer is not None:
            self.viewer.close()
            self.viewer = None
        return self.env.close()
# Out:
# /opt/conda/lib/python3.10/site-packages/glfw/__init__.py:916: GLFWError: (65544) b'X11: The DISPLAY environment variable is missing'
#   warnings.warn(message, GLFWError)

# %%
import wandb
wandb.login(key = "fc4f98ad0ffb2231a657df7c79439c6900855b20")
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# env = DMSuiteEnv("cheetah","run")

# %%
# corrected_script_path = "/kaggle/input/pinkie/r.py"
# new_file_path = "/opt/conda/lib/python3.10/site-packages/pink/sb3.py"

# with open(corrected_script_path, 'r') as corrected_script:
#     corrected_code = corrected_script.read()
    
# with open(new_file_path, "w") as new_file:
#     new_file.write(corrected_code)

# %%
# import torch
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# print(device)

# %%
import numpy as np
from numpy.fft import irfft, rfftfreq


def powerlaw_psd_gaussian(exponent, size, fmin=0, rng=None):
    """Gaussian (1/f)**beta noise.

    Based on the algorithm in:
    Timmer, J. and Koenig, M.:
    On generating power law noise.
    Astron. Astrophys. 300, 707-710 (1995)

    Normalised to unit variance

    Parameters:
    -----------

    exponent : float
        The power-spectrum of the generated noise is proportional to

        S(f) = (1 / f)**beta
        flicker / pink noise:   exponent beta = 1
        brown noise:            exponent beta = 2

        Furthermore, the autocorrelation decays proportional to lag**-gamma
        with gamma = 1 - beta for 0 < beta < 1.
        There may be finite-size issues for beta close to one.

    shape : int or iterable
        The output has the given shape, and the desired power spectrum in
        the last coordinate. That is, the last dimension is taken as time,
        and all other components are independent.

    fmin : float, optional
        Low-frequency cutoff.
        Default: 0 corresponds to original paper.

        The power-spectrum below fmin is flat. fmin is defined relative
        to a unit sampling rate (see numpy's rfftfreq). For convenience,
        the passed value is mapped to max(fmin, 1/samples) internally
        since 1/samples is the lowest possible finite frequency in the
        sample. The largest possible value is fmin = 0.5, the Nyquist
        frequency. The output for this value is white noise.

    rng : np.random.Generator, optional
        Random number generator (for reproducibility). If not passed, a new
        random number generator is created by calling
        `np.random.default_rng()`.


    Returns
    -------
    out : array
        The samples.


    Examples:
    ---------

    >>> # generate 1/f noise == pink noise == flicker noise
    >>> import colorednoise as cn
    >>> y = cn.powerlaw_psd_gaussian(1, 5)
    """

    # Make sure size is a list so we can iterate it and assign to it.
    try:
        size = list(size)
    except TypeError:
        size = [size]

    # The number of samples in each time series
    samples = size[-1]

    # Calculate Frequencies (we asume a sample rate of one)
    # Use fft functions for real output (-> hermitian spectrum)
    f = rfftfreq(samples)

    # Validate / normalise fmin
    if 0 <= fmin <= 0.5:
        fmin = max(fmin, 1./samples)    # Low frequency cutoff
    else:
        raise ValueError("fmin must be chosen between 0 and 0.5.")

    # Build scaling factors for all frequencies
    s_scale = f
    ix = np.sum(s_scale < fmin)   # Index of the cutoff
    if ix and ix < len(s_scale):
        s_scale[:ix] = s_scale[ix]
    s_scale = s_scale**(-exponent/2.)

    # Calculate theoretical output standard deviation from scaling
    w = s_scale[1:].copy()
    w[-1] *= (1 + (samples % 2)) / 2.    # correct f = +-0.5
    sigma = 2 * np.sqrt(np.sum(w**2)) / samples

    # Adjust size to generate one Fourier component per frequency
    size[-1] = len(f)

    # Add empty dimension(s) to broadcast s_scale along last
    # dimension of generated random power + phase (below)
    dims_to_add = len(size) - 1
    s_scale = s_scale[(None,) * dims_to_add + (Ellipsis,)]

    # Generate scaled random power + phase
    if rng is None:
        rng = np.random.default_rng()
    sr = rng.normal(scale=s_scale, size=size)
    si = rng.normal(scale=s_scale, size=size)

    # If the signal length is even, frequencies +/- 0.5 are equal
    # so the coefficient must be real.
    if not (samples % 2):
        si[..., -1] = 0
        sr[..., -1] *= np.sqrt(2)    # Fix magnitude

    # Regardless of signal length, the DC component must be real
    si[..., 0] = 0
    sr[..., 0] *= np.sqrt(2)    # Fix magnitude

    # Combine power + corrected phase to Fourier components
    s = sr + 1J * si

    # Transform to real time series & scale to unit variance
    y = irfft(s, n=samples, axis=-1) / sigma

    return y

# %%
class ColoredNoiseProcess():
    """Colored noise implemented as a process that allows subsequent samples.
    Implemented as a buffer; every "chunksize[-1]" items, a cut to a new time series starts.
    """

    def __init__(self, beta=1, scale=1, chunksize=32768, largest_wavelength=256, rng=None):
        self.beta = beta
        if largest_wavelength is None:
            self.minimum_frequency = 0
        else:
            self.minimum_frequency = 1 / largest_wavelength
        self.scale = scale
        self.rng = rng

        # The last component of chunksize is the time index
        try:
            self.chunksize = list(chunksize)
        except TypeError:
            self.chunksize = [chunksize]
        self.time_steps = self.chunksize[-1]

        # Set first time-step such that buffer will be initialized
        self.idx = self.time_steps

    def sample(self):
        self.idx += 1    # Next time step

        # Refill buffer if depleted
        if self.idx >= self.time_steps:
            self.buffer = powerlaw_psd_gaussian(
                exponent=self.beta, size=self.chunksize, fmin=self.minimum_frequency, rng=self.rng)
            self.idx = 0

        return self.scale * self.buffer[..., self.idx]

# %%
from stable_baselines3.common.distributions import SquashedDiagGaussianDistribution
from stable_baselines3.common.noise import ActionNoise

class SquashedDiagCNDistribution(SquashedDiagGaussianDistribution):
    """
    Colored Noise distribution with diagonal covariance matrix, followed by a squashing function (tanh) to ensure
    bounds. Used for Soft Actor-Critic with colored noise exploration in lieu of SquashedDiagGaussianDistribution.

    :param action_dim: Dimension of the action space.
    :param epsilon: small value to avoid NaN due to numerical imprecision.
    """

    def __init__(self, action_dim: int, beta: np.ndarray, seq_len, epsilon: float = 1e-6, rng=None):
        super().__init__(action_dim, epsilon)
        self.cn_processes = [ColoredNoiseProcess(beta=b, chunksize=seq_len, largest_wavelength=None, rng=rng)
                             for b in beta]

    def sample(self) -> th.Tensor:
        cn_sample = th.tensor([cnp.sample() for cnp in self.cn_processes]).float()
        cn_sample = cn_sample.to(device)
        self.gaussian_actions = self.distribution.mean + self.distribution.stddev*cn_sample
        return th.tanh(self.gaussian_actions)
    
    
class ColoredActionNoise(ActionNoise):
    """Action noise using colored noise processes (independent for each action dimension)."""
    def __init__(self, beta, sigma, seq_len, action_dim=None, rng=None):
        super().__init__()
        assert (action_dim is not None) == np.isscalar(beta), \
            "`action_dim` has to be specified if and only if `beta` is a scalar."

        self.sigma = np.full(action_dim or len(beta), sigma) if np.isscalar(sigma) else np.asarray(sigma)

        if np.isscalar(beta):
            self.beta = beta
            self.gen = ColoredNoiseProcess(beta=self.beta, scale=self.sigma, size=(action_dim, seq_len), rng=rng)
        else:
            self.beta = np.asarray(beta)
            self.gen = [ColoredNoiseProcess(beta=b, scale=s, size=seq_len, rng=rng)
                        for b, s in zip(self.beta, self.sigma)]

    def __call__(self) -> np.ndarray:
        return self.gen.sample() if np.isscalar(self.beta) else np.asarray([g.sample() for g in self.gen])

    def __repr__(self) -> str:
        return f"ColoredActionNoise(beta={self.beta}, sigma={self.sigma})"
# Out:
# 2024-02-13 20:55:43.240380: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-13 20:55:43.240485: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-13 20:55:43.378285: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
class GenEnv():
    """Generate gym environment from string with new seed each time"""
    def __init__(self, seed, sparse_reward=False, tonic=False):
        self.env = DMSuiteEnv("cheetah","run")
        self.seed = seed
        self.sparse_reward = sparse_reward
        self.tonic = tonic

    def __call__(self, get_policy=False):
        policy = "MlpPolicy"
        env = DMSuiteEnv("cheetah","run")

        if self.sparse_reward:
            env.step_ = env.step

            def step(env, a):
                obs, _, done, info = env.step_(a)
                return obs, int(info['goal_achieved']), done, info

            env.step = MethodType(step, env)

        self.seed += 1    # Change seed such that it is different each time the environment is created

        if get_policy:
            return env, policy
        return env

# %%
from stable_baselines3.common.callbacks import BaseCallback

class MonitorCallback(BaseCallback):
    """Simple SB3 callback for monitoring episode returns and lengths. Also shows a progress bar."""
    def __init__(self, gen_env, save=False, eval_every=10_000, n_eval=5):
        super().__init__()
        self.save = save
        self.env = gen_env()
        self.eval_every = eval_every    # Every eval_every interactions, commence evaluation step
        self.n_eval = n_eval            # Number of evaluation episodes per evaluation step
        self.episode_returns = []
        self.episode_lengths = []
        self.evaluation_returns = []
        self.monitor = {'episode_returns': self.episode_returns, 'episode_lengths': self.episode_lengths,
                        'evaluation_returns': self.evaluation_returns}

    def _on_training_start(self):
        self.n_actions = self.training_env.action_space.shape[-1]
        self.episode_returns.append(0)
        self.episode_lengths.append(0)

        # Progress bar

    def _on_training_end(self):
        # Save data and close progress bar
        pass

    def _on_step(self):

        # Store reward
        self.episode_returns[-1] += self.locals['rewards'].item()
        self.episode_lengths[-1] += 1
        if self.locals['dones'].item():
            self.episode_returns.append(0)
            self.episode_lengths.append(0)

        # Evaluation Rollouts
        if self.num_timesteps == 1 or self.num_timesteps % self.eval_every == 0:
            returns = np.zeros(self.n_eval)
            for i in range(self.n_eval):
                obs = self.env.reset()
                done = False
                while not done:
                    action = self.model.predict(obs, deterministic=True)[0]
                    obs, reward, done, _ = self.env.step(action)
                    returns[i] += reward
            self.evaluation_returns.append((self.num_timesteps, returns))


class ScheduledColoredNoise(MonitorCallback):
    """Linear scheduling from colors[0] to colors[1]"""
    def __init__(self, gen_env, save=False, colors=(2, 0), method='linear', noise_scale=0.3, len_rollout=10_000,
                 rng=None, **monitor_kwargs):
        super().__init__(gen_env, save, **monitor_kwargs)
        self.colors = colors
        self.method = method              # 'linear' or 'atanh' scheduling
        self.noise_scale = noise_scale    # Colored noise process std
        self.len_rollout = len_rollout    # Number of interactions per rollout
        self.i = 0                        # Iteration counter
        self.rng = rng                    # Random number generator

        # Monitoring
        self.chosen_colors = []
        self.monitor['colors'] = self.chosen_colors

    def _on_training_start(self):
        super()._on_training_start()

        # Initialize agent noise
        self.beta = self.update_beta()

    def set_beta(self, beta, seq_len):
        if isinstance(self.model, SAC):
            # State-dependent action noise is a bit more difficult
            self.model.actor.action_dist = SquashedDiagCNDistribution(
                self.n_actions, beta, seq_len, rng=self.rng)
        else:
            # For TD3 or other non-state dependent action noise agents
            self.model.action_noise = ColoredActionNoise(
                beta, self.noise_scale * np.ones(self.n_actions), seq_len, rng=self.rng)

    def update_beta(self):
        """Select new beta parameter (randomly)"""
        # Calculate and apply beta
        x = self.num_timesteps / self.locals['total_timesteps']
        if self.method == 'linear':
            beta = (1 - x)*self.colors[0] + x*self.colors[1]
        elif self.method == 'atanh':
            beta = np.clip(np.arctanh(min(1 - x, 1 - 1e-6)), 0, 4)
        elif self.method == 'cosine':
            beta = self.colors[1] + 0.5 * (self.colors[0]-self.colors[1]) * (1+math.cos(math.pi*x))
        beta *= np.ones(self.n_actions)
        self.set_beta(beta, self.len_rollout)

        # Monitoring
        self.chosen_colors.append(beta)

        return beta

    def _on_step(self):
        super()._on_step()

        # Check if rollout is finished
        i = self.num_timesteps // self.len_rollout
        if i == self.i:
            return
        self.i = i

        # Select new beta and change noise process
        self.beta = self.update_beta()

# %%
def linear(x,start,stop):
    return (1-x)*start + x*stop

# %%
import math
def cosine(x,start,stop):
    return stop + 0.5 * (start-stop) * (1+math.cos(math.pi*x))

# %%
def atanh(x,start,stop):
    return np.clip(np.arctanh(min(1 - x, 1 - 1e-6)), 0, 4)

# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import SAC
import time
from tqdm import tqdm

# Define a function to evaluate an episode
def evaluate_episode(model, env):
    obs = env.reset()
    done = False
    total_reward = 0.0
    steps=0
    while steps<1000 and not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _ = env.step(action)
        total_reward += reward
        steps+=1
    return total_reward

# Reproducibility
seed = 69
np.random.seed(seed)
th.manual_seed(seed)
rng = np.random.default_rng(seed)

# Initialize environment

gen_env = GenEnv(seed=420)
dir_ = '.'
noise_scale = 0.3
env = gen_env(get_policy=False)
ep = 100
rng = np.random.default_rng(seed = 3939)
action_dim = env.action_space.shape[-1]
seq_len = 1000

start_linear = 2
stop_linear = 2
start_atanh = 2
stop_atanh = 2
start_cosine = 2
stop_cosine = 2

# Initialize agents
model_linear = SAC("MultiInputPolicy", env, seed = seed)
model_atanh = SAC("MultiInputPolicy", env, seed = seed)
model_cosine = SAC("MultiInputPolicy", env, seed=seed)


# Training parameters
total_timesteps = 1000000
eval_frequency = 10000 # Evaluate every 104 interactions
eval_rollouts = 5

wandb.init(
    project="Pinkie",
    config = {
    "Total_timesteps": total_timesteps,
    "Eval_frequency": eval_frequency,
    "Eval_rollouts": eval_rollouts
    }
)

#Final average performances
avg_linear=0.0
avg_cosine=0.0
avg_atanh=0.0
final_linear=0.0
final_cosine=0.0
final_atanh=0.0

# Train agents with evaluation
timesteps_so_far = 0
# for timesteps_so_far in tqdm(range(0,total_timesteps,eval_frequency)):
while timesteps_so_far < total_timesteps:
    
    timesteps_so_far += eval_frequency
    x = timesteps_so_far/total_timesteps
    start_linear = stop_linear
    stop_linear = linear(x,2,0)
    callback_linear = ScheduledColoredNoise(
                gen_env, dir_, (start_linear, stop_linear), 'linear', noise_scale,
                ep, rng)
    
    t1 = time.time()
    # Train the default noise model
#     print(model_linear.actor.action_dist.gen.beta)
    model_linear.learn(total_timesteps=eval_frequency, log_interval = 1,callback = callback_linear )
#     print(model_linear.actor.action_dist.gen.beta)
    t2 = time.time()

    # Evaluate the default noise model
    mean_return_linear = 0.0
    for _ in range(eval_rollouts):
        mean_return_linear += evaluate_episode(model_linear, env)
    mean_return_linear /= eval_rollouts
    avg_linear+=mean_return_linear
    if(timesteps_so_far>=0.95*total_timesteps):
        final_linear+=mean_return_linear

    print(f"Return (Linear): {mean_return_linear}")
    print(f"Time taken (Linear Model): {t2 - t1:.2f} seconds")
    print(f"Timesteps: {timesteps_so_far}, Mean Return: {mean_return_linear}")
    
    
    start_cosine = stop_cosine
    stop_cosine = cosine(x,2,0)
    callback_cosine = ScheduledColoredNoise(
                gen_env, dir_, (start_cosine, stop_cosine), 'linear', noise_scale,
                ep, rng)
    
    t1 = time.time()
    # Train the default noise model
#     print(model_cosine.actor.action_dist.gen.beta)
    model_cosine.learn(total_timesteps=eval_frequency,log_interval = 1, callback = callback_cosine)
#     print(model_cosine.actor.action_dist.gen.beta)
    t2 = time.time()

    # Evaluate the default noise model
    mean_return_cosine = 0.0
    for _ in range(eval_rollouts):
        mean_return_cosine += evaluate_episode(model_cosine, env)
    mean_return_cosine /= eval_rollouts
    avg_cosine+=mean_return_cosine
    if(timesteps_so_far>=0.95*total_timesteps):
        final_cosine+=mean_return_cosine

    print(f"Return (Cosine): {mean_return_cosine}")
    print(f"Time taken (Cosine Model): {t2 - t1:.2f} seconds")
    print(f"Timesteps: {timesteps_so_far}, Mean Return: {mean_return_cosine}")
    
    start_atanh = stop_atanh
    stop_atanh = atanh(x,2,0)
    callback_atanh = ScheduledColoredNoise(
                gen_env, dir_, (start_atanh, stop_atanh), 'linear', noise_scale,
                ep, rng)
    
    t1 = time.time()
    # Train the default noise model
#     print(model_atanh.actor.action_dist.gen.beta)
    model_atanh.learn(total_timesteps=eval_frequency,log_interval = 1,callback = callback_atanh)
#     print(model_atanh.actor.action_dist.gen.beta)
    t2 = time.time()

    # Evaluate the default noise model
    mean_return_atanh = 0.0
    for _ in range(eval_rollouts):
        mean_return_atanh += evaluate_episode(model_atanh, env)
    mean_return_atanh /= eval_rollouts
    avg_atanh+=mean_return_atanh
    if(timesteps_so_far>=0.95*total_timesteps):
        final_atanh+=mean_return_atanh

    print(f"Return (Atanh): {mean_return_atanh}")
    print(f"Time taken (Atanh Model): {t2 - t1:.2f} seconds")
    print(f"Timesteps: {timesteps_so_far}, Mean Return: {mean_return_atanh}")
    
    wandb.log({
        "mean_return_linear": mean_return_linear,
        "timesteps_so_far": timesteps_so_far,
        "mean_return_cosine": mean_return_cosine,
        "mean_return_atanh": mean_return_atanh,
        "linear_beta": stop_linear,
        "cosine_beta": stop_cosine,
        "atanh_beta": stop_atanh
    })

avg_linear/=(total_timesteps/eval_frequency)
avg_cosine/=(total_timesteps/eval_frequency)
avg_atanh/=(total_timesteps/eval_frequency)

final_linear/=(0.05*total_timesteps/eval_frequency)
final_cosine/=(0.05*total_timesteps/eval_frequency)
final_atanh/=(0.05*total_timesteps/eval_frequency)

wandb.log({
    "final_linear": final_linear,
    "final_cosine": final_cosine,
    "final_atanh": final_atanh,
    "avg_linear": avg_linear,
    "avg_cosine": avg_cosine,
    "avg_atanh": avg_atanh
})

print("Mean:")
print(f"Linear:{avg_linear}           Cosine:{avg_cosine}             atanh:{avg_atanh}")
print("Final:")
print(f"Linear:{final_linear}           Cosine:{final_cosine}             atanh:{final_atanh}")
# Out:
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# /opt/conda/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# wandb: Currently logged in as: cathedr4l (rl_team_1). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.16.2
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20240213_205555-cmekfce7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run brilliant-rooster-217
# wandb: ⭐️ View project at https://wandb.ai/rl_team_1/Pinkie
# wandb: 🚀 View run at https://wandb.ai/rl_team_1/Pinkie/runs/cmekfce7
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 42.155118039659484
# Time taken (Linear Model): 130.02 seconds
# Timesteps: 10000, Mean Return: 42.155118039659484
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 11.754665398760508
# Time taken (Cosine Model): 128.33 seconds
# Timesteps: 10000, Mean Return: 11.754665398760508
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 5.244381931745698
# Time taken (Atanh Model): 129.33 seconds
# Timesteps: 10000, Mean Return: 5.244381931745698
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 71.07471333320991
# Time taken (Linear Model): 129.17 seconds
# Timesteps: 20000, Mean Return: 71.07471333320991
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 44.176119338767634
# Time taken (Cosine Model): 128.67 seconds
# Timesteps: 20000, Mean Return: 44.176119338767634
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 40.43293606616588
# Time taken (Atanh Model): 128.42 seconds
# Timesteps: 20000, Mean Return: 40.43293606616588
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 49.67682452521996
# Time taken (Linear Model): 128.74 seconds
# Timesteps: 30000, Mean Return: 49.67682452521996
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 86.89094517071302
# Time taken (Cosine Model): 128.53 seconds
# Timesteps: 30000, Mean Return: 86.89094517071302
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 45.27530879886169
# Time taken (Atanh Model): 128.68 seconds
# Timesteps: 30000, Mean Return: 45.27530879886169
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 59.882117624455546
# Time taken (Linear Model): 129.38 seconds
# Timesteps: 40000, Mean Return: 59.882117624455546
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 96.05203547512315
# Time taken (Cosine Model): 128.80 seconds
# Timesteps: 40000, Mean Return: 96.05203547512315
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 54.11472194374555
# Time taken (Atanh Model): 134.03 seconds
# Timesteps: 40000, Mean Return: 54.11472194374555
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 115.24519776371797
# Time taken (Linear Model): 130.96 seconds
# Timesteps: 50000, Mean Return: 115.24519776371797
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 86.04434877271433
# Time taken (Cosine Model): 130.37 seconds
# Timesteps: 50000, Mean Return: 86.04434877271433
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 81.71771198301926
# Time taken (Atanh Model): 129.75 seconds
# Timesteps: 50000, Mean Return: 81.71771198301926
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 84.83466648464291
# Time taken (Linear Model): 130.53 seconds
# Timesteps: 60000, Mean Return: 84.83466648464291
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 107.60239576287856
# Time taken (Cosine Model): 135.61 seconds
# Timesteps: 60000, Mean Return: 107.60239576287856
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 50.86595169171828
# Time taken (Atanh Model): 132.62 seconds
# Timesteps: 60000, Mean Return: 50.86595169171828
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 110.85905897967226
# Time taken (Linear Model): 132.15 seconds
# Timesteps: 70000, Mean Return: 110.85905897967226
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 112.77303040206706
# Time taken (Cosine Model): 131.94 seconds
# Timesteps: 70000, Mean Return: 112.77303040206706
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 89.40014891800004
# Time taken (Atanh Model): 132.15 seconds
# Timesteps: 70000, Mean Return: 89.40014891800004
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 94.18542224286418
# Time taken (Linear Model): 132.74 seconds
# Timesteps: 80000, Mean Return: 94.18542224286418
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 110.00764830003804
# Time taken (Cosine Model): 132.22 seconds
# Timesteps: 80000, Mean Return: 110.00764830003804
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 87.01865564215373
# Time taken (Atanh Model): 130.95 seconds
# Timesteps: 80000, Mean Return: 87.01865564215373
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 81.46128245936917
# Time taken (Linear Model): 132.81 seconds
# Timesteps: 90000, Mean Return: 81.46128245936917
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 119.39352221617658
# Time taken (Cosine Model): 130.84 seconds
# Timesteps: 90000, Mean Return: 119.39352221617658
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 146.95068874831043
# Time taken (Atanh Model): 134.11 seconds
# Timesteps: 90000, Mean Return: 146.95068874831043
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 105.33511195014121
# Time taken (Linear Model): 131.06 seconds
# Timesteps: 100000, Mean Return: 105.33511195014121
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 200.5806449211393
# Time taken (Cosine Model): 133.88 seconds
# Timesteps: 100000, Mean Return: 200.5806449211393
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 88.49558454789401
# Time taken (Atanh Model): 130.89 seconds
# Timesteps: 100000, Mean Return: 88.49558454789401
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 157.79790760376906
# Time taken (Linear Model): 133.53 seconds
# Timesteps: 110000, Mean Return: 157.79790760376906
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 168.2791981007871
# Time taken (Cosine Model): 132.02 seconds
# Timesteps: 110000, Mean Return: 168.2791981007871
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 172.05574814511778
# Time taken (Atanh Model): 133.78 seconds
# Timesteps: 110000, Mean Return: 172.05574814511778
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 172.7125931262161
# Time taken (Linear Model): 131.17 seconds
# Timesteps: 120000, Mean Return: 172.7125931262161
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 304.15316831540565
# Time taken (Cosine Model): 133.47 seconds
# Timesteps: 120000, Mean Return: 304.15316831540565
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 193.2292308600514
# Time taken (Atanh Model): 130.88 seconds
# Timesteps: 120000, Mean Return: 193.2292308600514
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 134.80646365835943
# Time taken (Linear Model): 134.03 seconds
# Timesteps: 130000, Mean Return: 134.80646365835943
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 383.26040488036375
# Time taken (Cosine Model): 131.83 seconds
# Timesteps: 130000, Mean Return: 383.26040488036375
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 220.78996019191626
# Time taken (Atanh Model): 134.15 seconds
# Timesteps: 130000, Mean Return: 220.78996019191626
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 210.82665890443317
# Time taken (Linear Model): 132.80 seconds
# Timesteps: 140000, Mean Return: 210.82665890443317
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 138.6113697180625
# Time taken (Cosine Model): 134.64 seconds
# Timesteps: 140000, Mean Return: 138.6113697180625
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 247.3735435479307
# Time taken (Atanh Model): 130.69 seconds
# Timesteps: 140000, Mean Return: 247.3735435479307
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 237.5269584717371
# Time taken (Linear Model): 133.46 seconds
# Timesteps: 150000, Mean Return: 237.5269584717371
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 339.90640336222924
# Time taken (Cosine Model): 131.49 seconds
# Timesteps: 150000, Mean Return: 339.90640336222924
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 283.68069293525565
# Time taken (Atanh Model): 132.48 seconds
# Timesteps: 150000, Mean Return: 283.68069293525565
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 217.17454028431044
# Time taken (Linear Model): 131.61 seconds
# Timesteps: 160000, Mean Return: 217.17454028431044
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 420.83606669449944
# Time taken (Cosine Model): 131.90 seconds
# Timesteps: 160000, Mean Return: 420.83606669449944
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 305.20508409068447
# Time taken (Atanh Model): 133.14 seconds
# Timesteps: 160000, Mean Return: 305.20508409068447
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 357.4661267502145
# Time taken (Linear Model): 131.92 seconds
# Timesteps: 170000, Mean Return: 357.4661267502145
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 432.32510349542565
# Time taken (Cosine Model): 132.30 seconds
# Timesteps: 170000, Mean Return: 432.32510349542565
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 321.7106136786228
# Time taken (Atanh Model): 130.76 seconds
# Timesteps: 170000, Mean Return: 321.7106136786228
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 408.3964420723209
# Time taken (Linear Model): 133.21 seconds
# Timesteps: 180000, Mean Return: 408.3964420723209
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 396.2301379417445
# Time taken (Cosine Model): 132.70 seconds
# Timesteps: 180000, Mean Return: 396.2301379417445
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 402.75717549649073
# Time taken (Atanh Model): 134.05 seconds
# Timesteps: 180000, Mean Return: 402.75717549649073
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 267.96882988775377
# Time taken (Linear Model): 131.04 seconds
# Timesteps: 190000, Mean Return: 267.96882988775377
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 381.76052557365625
# Time taken (Cosine Model): 133.81 seconds
# Timesteps: 190000, Mean Return: 381.76052557365625
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 420.570438398937
# Time taken (Atanh Model): 131.10 seconds
# Timesteps: 190000, Mean Return: 420.570438398937
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 351.6220046154408
# Time taken (Linear Model): 133.83 seconds
# Timesteps: 200000, Mean Return: 351.6220046154408
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 472.23839393218105
# Time taken (Cosine Model): 132.90 seconds
# Timesteps: 200000, Mean Return: 472.23839393218105
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 355.514176411227
# Time taken (Atanh Model): 134.05 seconds
# Timesteps: 200000, Mean Return: 355.514176411227
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 461.3755649931043
# Time taken (Linear Model): 135.49 seconds
# Timesteps: 210000, Mean Return: 461.3755649931043
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 483.2109909678232
# Time taken (Cosine Model): 134.18 seconds
# Timesteps: 210000, Mean Return: 483.2109909678232
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 345.2851009570052
# Time taken (Atanh Model): 130.97 seconds
# Timesteps: 210000, Mean Return: 345.2851009570052
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 384.8277924699009
# Time taken (Linear Model): 136.23 seconds
# Timesteps: 220000, Mean Return: 384.8277924699009
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 470.7661957707959
# Time taken (Cosine Model): 131.97 seconds
# Timesteps: 220000, Mean Return: 470.7661957707959
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 277.0585818144181
# Time taken (Atanh Model): 134.05 seconds
# Timesteps: 220000, Mean Return: 277.0585818144181
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 281.1735821915121
# Time taken (Linear Model): 132.34 seconds
# Timesteps: 230000, Mean Return: 281.1735821915121
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 427.4593500727991
# Time taken (Cosine Model): 133.46 seconds
# Timesteps: 230000, Mean Return: 427.4593500727991
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 302.4551035501071
# Time taken (Atanh Model): 132.59 seconds
# Timesteps: 230000, Mean Return: 302.4551035501071
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 478.17264512965164
# Time taken (Linear Model): 133.38 seconds
# Timesteps: 240000, Mean Return: 478.17264512965164
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 467.46984841708706
# Time taken (Cosine Model): 132.25 seconds
# Timesteps: 240000, Mean Return: 467.46984841708706
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 242.0653948158486
# Time taken (Atanh Model): 132.22 seconds
# Timesteps: 240000, Mean Return: 242.0653948158486
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 456.32779572197234
# Time taken (Linear Model): 132.47 seconds
# Timesteps: 250000, Mean Return: 456.32779572197234
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 537.4191692576754
# Time taken (Cosine Model): 132.27 seconds
# Timesteps: 250000, Mean Return: 537.4191692576754
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 525.111701296795
# Time taken (Atanh Model): 135.87 seconds
# Timesteps: 250000, Mean Return: 525.111701296795
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 327.7159105774841
# Time taken (Linear Model): 132.41 seconds
# Timesteps: 260000, Mean Return: 327.7159105774841
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 530.2047923921793
# Time taken (Cosine Model): 131.57 seconds
# Timesteps: 260000, Mean Return: 530.2047923921793
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 487.4095206457462
# Time taken (Atanh Model): 132.31 seconds
# Timesteps: 260000, Mean Return: 487.4095206457462
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 421.9777203845391
# Time taken (Linear Model): 131.67 seconds
# Timesteps: 270000, Mean Return: 421.9777203845391
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 456.4832459620915
# Time taken (Cosine Model): 130.91 seconds
# Timesteps: 270000, Mean Return: 456.4832459620915
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 538.2801467441566
# Time taken (Atanh Model): 132.15 seconds
# Timesteps: 270000, Mean Return: 538.2801467441566
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 469.6211137433872
# Time taken (Linear Model): 130.03 seconds
# Timesteps: 280000, Mean Return: 469.6211137433872
# ...
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 676.852430348738
# Time taken (Cosine Model): 130.95 seconds
# Timesteps: 910000, Mean Return: 676.852430348738
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 638.6089846409343
# Time taken (Atanh Model): 130.84 seconds
# Timesteps: 910000, Mean Return: 638.6089846409343
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 662.7855277088144
# Time taken (Linear Model): 130.56 seconds
# Timesteps: 920000, Mean Return: 662.7855277088144
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 597.4312654997905
# Time taken (Cosine Model): 131.00 seconds
# Timesteps: 920000, Mean Return: 597.4312654997905
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 648.438282525593
# Time taken (Atanh Model): 131.53 seconds
# Timesteps: 920000, Mean Return: 648.438282525593
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 622.1160862116478
# Time taken (Linear Model): 134.15 seconds
# Timesteps: 930000, Mean Return: 622.1160862116478
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 695.3236937934939
# Time taken (Cosine Model): 133.18 seconds
# Timesteps: 930000, Mean Return: 695.3236937934939
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 677.8313290435204
# Time taken (Atanh Model): 130.57 seconds
# Timesteps: 930000, Mean Return: 677.8313290435204
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 637.9447180546525
# Time taken (Linear Model): 131.81 seconds
# Timesteps: 940000, Mean Return: 637.9447180546525
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 717.0586445168321
# Time taken (Cosine Model): 131.35 seconds
# Timesteps: 940000, Mean Return: 717.0586445168321
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 732.9428326822979
# Time taken (Atanh Model): 132.71 seconds
# Timesteps: 940000, Mean Return: 732.9428326822979
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 664.8423894487423
# Time taken (Linear Model): 131.25 seconds
# Timesteps: 950000, Mean Return: 664.8423894487423
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 712.5779762682198
# Time taken (Cosine Model): 130.82 seconds
# Timesteps: 950000, Mean Return: 712.5779762682198
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 728.4162251636042
# Time taken (Atanh Model): 130.58 seconds
# Timesteps: 950000, Mean Return: 728.4162251636042
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 627.370437210082
# Time taken (Linear Model): 131.06 seconds
# Timesteps: 960000, Mean Return: 627.370437210082
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 738.8418673817656
# Time taken (Cosine Model): 132.85 seconds
# Timesteps: 960000, Mean Return: 738.8418673817656
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 671.342101445953
# Time taken (Atanh Model): 135.66 seconds
# Timesteps: 960000, Mean Return: 671.342101445953
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 667.2115329373825
# Time taken (Linear Model): 132.54 seconds
# Timesteps: 970000, Mean Return: 667.2115329373825
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 740.2989726301746
# Time taken (Cosine Model): 131.49 seconds
# Timesteps: 970000, Mean Return: 740.2989726301746
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 727.7342043584588
# Time taken (Atanh Model): 131.28 seconds
# Timesteps: 970000, Mean Return: 727.7342043584588
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 650.1550743939157
# Time taken (Linear Model): 131.54 seconds
# Timesteps: 980000, Mean Return: 650.1550743939157
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 703.6237008188837
# Time taken (Cosine Model): 130.94 seconds
# Timesteps: 980000, Mean Return: 703.6237008188837
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 696.0370165321499
# Time taken (Atanh Model): 130.41 seconds
# Timesteps: 980000, Mean Return: 696.0370165321499
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 621.3210027006693
# Time taken (Linear Model): 131.01 seconds
# Timesteps: 990000, Mean Return: 621.3210027006693
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 770.8869814086358
# Time taken (Cosine Model): 131.44 seconds
# Timesteps: 990000, Mean Return: 770.8869814086358
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 713.5355600486872
# Time taken (Atanh Model): 131.32 seconds
# Timesteps: 990000, Mean Return: 713.5355600486872
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Linear): 648.0970676560446
# Time taken (Linear Model): 133.48 seconds
# Timesteps: 1000000, Mean Return: 648.0970676560446
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Cosine): 684.2850584233146
# Time taken (Cosine Model): 135.68 seconds
# Timesteps: 1000000, Mean Return: 684.2850584233146
# OrderedDict([('position', Array(shape=(8,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (8,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# Return (Atanh): 716.4116498060146
# Time taken (Atanh Model): 133.66 seconds
# Timesteps: 1000000, Mean Return: 716.4116498060146
# Mean:
# Linear:496.84940526003834           Cosine:535.2682774012455             atanh:525.0727502750889
# Final:
# Linear:775.7995008693672           Cosine:870.1029113861989             atanh:850.6953514709736

# %%
env = DMSuiteEnv("cartpole","balance_sparse")
env = DMSuiteEnv("cartpole","swingup_sparse")
env = DMSuiteEnv("ball_in_cup","catch")
env = DMSuiteEnv("hopper","hop")
env = DMSuiteEnv("walker","run")
env = DMSuiteEnv("reacher","hard")
env = DMSuiteEnv("pendulum","swingup")
# Out:
# OrderedDict([('position', Array(shape=(3,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(2,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (3,), float64), 'velocity': Box(-inf, inf, (2,), float64))
# ________________________
# BoundedArray(shape=(1,), dtype=dtype('float64'), name=None, minimum=[-1.], maximum=[1.])
# Box(-1.0, 1.0, (1,), float64)
# OrderedDict([('position', Array(shape=(3,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(2,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (3,), float64), 'velocity': Box(-inf, inf, (2,), float64))
# ________________________
# BoundedArray(shape=(1,), dtype=dtype('float64'), name=None, minimum=[-1.], maximum=[1.])
# Box(-1.0, 1.0, (1,), float64)
# OrderedDict([('position', Array(shape=(4,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(4,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (4,), float64), 'velocity': Box(-inf, inf, (4,), float64))
# ________________________
# BoundedArray(shape=(2,), dtype=dtype('float64'), name=None, minimum=[-1. -1.], maximum=[1. 1.])
# Box(-1.0, 1.0, (2,), float64)
# OrderedDict([('position', Array(shape=(6,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(7,), dtype=dtype('float64'), name='velocity')), ('touch', Array(shape=(2,), dtype=dtype('float64'), name='touch'))])
# Dict('position': Box(-inf, inf, (6,), float64), 'touch': Box(-inf, inf, (2,), float64), 'velocity': Box(-inf, inf, (7,), float64))
# ________________________
# BoundedArray(shape=(4,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1.], maximum=[1. 1. 1. 1.])
# Box(-1.0, 1.0, (4,), float64)
# OrderedDict([('orientations', Array(shape=(14,), dtype=dtype('float64'), name='orientations')), ('height', Array(shape=(), dtype=dtype('float64'), name='height')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
# Dict('height': Box(-inf, inf, (), float64), 'orientations': Box(-inf, inf, (14,), float64), 'velocity': Box(-inf, inf, (9,), float64))
# ________________________
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
# Box(-1.0, 1.0, (6,), float64)
# OrderedDict([('position', Array(shape=(2,), dtype=dtype('float64'), name='position')), ('to_target', Array(shape=(2,), dtype=dtype('float64'), name='to_target')), ('velocity', Array(shape=(2,), dtype=dtype('float64'), name='velocity'))])
# Dict('position': Box(-inf, inf, (2,), float64), 'to_target': Box(-inf, inf, (2,), float64), 'velocity': Box(-inf, inf, (2,), float64))
# ________________________
# BoundedArray(shape=(2,), dtype=dtype('float64'), name=None, minimum=[-1. -1.], maximum=[1. 1.])
# Box(-1.0, 1.0, (2,), float64)
# OrderedDict([('orientation', Array(shape=(2,), dtype=dtype('float64'), name='orientation')), ('velocity', Array(shape=(1,), dtype=dtype('float64'), name='velocity'))])
# Dict('orientation': Box(-inf, inf, (2,), float64), 'velocity': Box(-inf, inf, (1,), float64))
# ________________________
# BoundedArray(shape=(1,), dtype=dtype('float64'), name=None, minimum=[-1.], maximum=[1.])
# Box(-1.0, 1.0, (1,), float64)
