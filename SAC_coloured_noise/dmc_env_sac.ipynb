# %%
# !pip install dm_control
# !pip install pink-noise-rl
# !pip install wandb
# Out:
# Collecting dm_control
#
#   Downloading dm_control-1.0.16-py3-none-any.whl.metadata (1.3 kB)
#
# Requirement already satisfied: absl-py>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from dm_control) (1.4.0)
#
# Collecting dm-env (from dm_control)
#
#   Downloading dm_env-1.6-py3-none-any.whl (26 kB)
#
# Requirement already satisfied: dm-tree!=0.1.2 in /opt/conda/lib/python3.10/site-packages (from dm_control) (0.1.8)
#
# Collecting glfw (from dm_control)
#
#   Downloading glfw-2.6.5-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl.metadata (5.4 kB)
#
# Collecting labmaze (from dm_control)
#
#   Downloading labmaze-1.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 58.6 MB/s eta 0:00:00
#
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from dm_control) (5.1.0)
#
# Collecting mujoco>=3.1.1 (from dm_control)
#
#   Downloading mujoco-3.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.7 MB/s eta 0:00:00
#
# Requirement already satisfied: numpy>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from dm_control) (1.24.4)
#
# Requirement already satisfied: protobuf>=3.19.4 in /opt/conda/lib/python3.10/site-packages (from dm_control) (3.20.3)
#
# Collecting pyopengl>=3.1.4 (from dm_control)
#
#   Downloading PyOpenGL-3.1.7-py3-none-any.whl.metadata (3.2 kB)
#
# Requirement already satisfied: pyparsing>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from dm_control) (3.1.1)
#
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from dm_control) (2.31.0)
#
# Requirement already satisfied: setuptools!=50.0.0 in /opt/conda/lib/python3.10/site-packages (from dm_control) (69.0.3)
#
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from dm_control) (1.11.4)
#
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from dm_control) (4.66.1)
#
# Requirement already satisfied: etils[epath] in /opt/conda/lib/python3.10/site-packages (from mujoco>=3.1.1->dm_control) (1.6.0)
#
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->dm_control) (3.3.2)
#
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->dm_control) (3.6)
#
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->dm_control) (1.26.18)
#
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->dm_control) (2023.11.17)
#
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from etils[epath]->mujoco>=3.1.1->dm_control) (2023.12.2)
#
# Requirement already satisfied: importlib_resources in /opt/conda/lib/python3.10/site-packages (from etils[epath]->mujoco>=3.1.1->dm_control) (6.1.1)
#
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.10/site-packages (from etils[epath]->mujoco>=3.1.1->dm_control) (4.9.0)
#
# Requirement already satisfied: zipp in /opt/conda/lib/python3.10/site-packages (from etils[epath]->mujoco>=3.1.1->dm_control) (3.17.0)
#
# Downloading dm_control-1.0.16-py3-none-any.whl (55.4 MB)
#
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 MB 30.4 MB/s eta 0:00:00
#
# Downloading mujoco-3.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 94.1 MB/s eta 0:00:00
#
# Downloading PyOpenGL-3.1.7-py3-none-any.whl (2.4 MB)
#
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 67.3 MB/s eta 0:00:00
#
# Downloading glfw-2.6.5-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl (211 kB)
#
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 kB 12.5 MB/s eta 0:00:00
#
# Installing collected packages: pyopengl, glfw, labmaze, dm-env, mujoco, dm_control
#
# Successfully installed dm-env-1.6 dm_control-1.0.16 glfw-2.6.5 labmaze-1.0.6 mujoco-3.1.1 pyopengl-3.1.7
#
# Collecting pink-noise-rl
#
#   Downloading pink_noise_rl-2.0.1-py3-none-any.whl (9.0 kB)
#
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pink-noise-rl) (1.24.4)
#
# Installing collected packages: pink-noise-rl
#
# Successfully installed pink-noise-rl-2.0.1
#
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.16.2)
#
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
#
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.41)
#
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.31.0)
#
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
#
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (1.39.2)
#
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
#
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.1)
#
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
#
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (69.0.3)
#
# Requirement already satisfied: appdirs>=1.4.3 in /opt/conda/lib/python3.10/site-packages (from wandb) (1.4.4)
#
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
#
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
#
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.11)
#
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
#
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.6)
#
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
#
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2023.11.17)
#
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.1)

# %%
import gym
from gym import spaces

from dm_control import suite
from dm_env import specs


def convert_dm_control_to_gym_space(dm_control_space):
    r"""Convert dm_control space to gym space. """
    if isinstance(dm_control_space, specs.BoundedArray):
        space = spaces.Box(low=dm_control_space.minimum, 
                           high=dm_control_space.maximum, 
                           dtype=dm_control_space.dtype)
        assert space.shape == dm_control_space.shape
        return space
    elif isinstance(dm_control_space, specs.Array) and not isinstance(dm_control_space, specs.BoundedArray):
        space = spaces.Box(low=-float('inf'), 
                           high=float('inf'), 
                           shape=dm_control_space.shape, 
                           dtype=dm_control_space.dtype)
        return space
    elif isinstance(dm_control_space, dict):
        space = spaces.Dict({key: convert_dm_control_to_gym_space(value)
                             for key, value in dm_control_space.items()})
        return space


class DMSuiteEnv(gym.Env):
    def __init__(self, domain_name, task_name, task_kwargs=None, environment_kwargs=None, visualize_reward=False):
        self.env = suite.load(domain_name, 
                              task_name, 
                              task_kwargs=task_kwargs, 
                              environment_kwargs=environment_kwargs, 
                              visualize_reward=visualize_reward)
        self.metadata = {'render.modes': ['human', 'rgb_array'],
                         'video.frames_per_second': round(1.0/self.env.control_timestep())}
        print(self.env.observation_spec())
        self.observation_space = convert_dm_control_to_gym_space(self.env.observation_spec())
        print(self.observation_space)
        print("________________________")
        print(self.env.action_spec())
        self.action_space = convert_dm_control_to_gym_space(self.env.action_spec())
        print(self.action_space)
        self.viewer = None
    
    def seed(self, seed):
        return self.env.task.random.seed(seed)
    
    def step(self, action):
        timestep = self.env.step(action)
        observation = timestep.observation
        reward = timestep.reward
        done = timestep.last()
        info = {}
        truncated = False
        return observation, reward, done, info
    
    def reset(self):
        timestep = self.env.reset()
        return timestep.observation
    
    def render(self, mode='human', **kwargs):
        if 'camera_id' not in kwargs:
            kwargs['camera_id'] = 0  # Tracking camera
        use_opencv_renderer = kwargs.pop('use_opencv_renderer', False)
        
        img = self.env.physics.render(**kwargs)
        if mode == 'rgb_array':
            return img
        elif mode == 'human':
            if self.viewer is None:
                if not use_opencv_renderer:
                    from gym.envs.classic_control import rendering
                    self.viewer = rendering.SimpleImageViewer(maxwidth=1024)
                else:
                    from . import OpenCVImageViewer
                    self.viewer = OpenCVImageViewer()
            self.viewer.imshow(img)
            return self.viewer.isopen
        else:
            raise NotImplementedError

    def close(self):
        if self.viewer is not None:
            self.viewer.close()
            self.viewer = None
        return self.env.close()
# Out:
# /opt/conda/lib/python3.10/site-packages/glfw/__init__.py:916: GLFWError: (65544) b'X11: The DISPLAY environment variable is missing'
#
#   warnings.warn(message, GLFWError)

# %%
env1 = ["cartpole", "cartpole", "ball_in_cup", "hopper", "cheetah", "reacher", "pendulum"]
env2 = ["balance_sparse","swingup_sparse","catch","hop","run","hard","swingup"]

# %%
corrected_script_path = "/kaggle/input/pinkie/r.py"
new_file_path = "/opt/conda/lib/python3.10/site-packages/pink/sb3.py"

with open(corrected_script_path, 'r') as corrected_script:
    corrected_code = corrected_script.read()
    
with open(new_file_path, "w") as new_file:
    new_file.write(corrected_code)

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
print(device)
# Out:
# cuda

# %%
import gymnasium as gym
import numpy as np
import torch
from pink import PinkNoiseDist
from pink import ColoredNoiseDist
from stable_baselines3 import SAC
import time
from tqdm import tqdm

# Define a function to evaluate an episode
def evaluate_episode(model, env):
    obs = env.reset()
    done = False
    total_reward = 0.0
    steps=0
    while steps<1000 and not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _ = env.step(action)
        total_reward += reward
        steps+=1
    return total_reward

# Reproducibility
seed = 0
np.random.seed(seed)
torch.manual_seed(seed)
rng = np.random.default_rng(seed)

for i in range(7):
    env = DMSuiteEnv(env1[i],env2[i])
    action_dim = env.action_space.shape[-1]
    seq_len = 1000
    rng = np.random.default_rng(0)

    # Initialize agents
    model_default = SAC("MultiInputPolicy", env, seed=seed)
    model_pink = SAC("MultiInputPolicy", env, seed=seed)
    model_OU = SAC("MultiInputPolicy", env, seed=seed)

    # Set action noise
    model_pink.actor.action_dist = PinkNoiseDist(seq_len, action_dim, rng=rng)
    model_OU.actor.action_dist = ColoredNoiseDist(beta=2, seq_len=seq_len, action_dim=action_dim, rng=rng)

    # Training parameters
    total_timesteps = 1000000
    eval_frequency = 10000 # Evaluate every 104 interactions
    eval_rollouts = 5

    wandb.init(
        project="Pinkie",
        config = {
        "Total_timesteps": total_timesteps,
        "Eval_frequency": eval_frequency,
        "Eval_rollouts": eval_rollouts,
        "Environment": env1[i] + " " + env2[i]
        }
    )

    #Final average performances
    avg_default=0.0
    avg_pink=0.0
    avg_OU=0.0
    final_default=0.0
    final_pink=0.0
    final_OU=0.0

    # Train agents with evaluation
    timesteps_so_far = 0
    # for timesteps_so_far in tqdm(range(0,total_timesteps,eval_frequency)):
    while timesteps_so_far < total_timesteps:
        t1 = time.time()
        # Train the default noise model
        model_default.learn(total_timesteps=eval_frequency)
        t2 = time.time()

        # Evaluate the default noise model
        mean_return_default = 0.0
        for _ in range(eval_rollouts):
            mean_return_default += evaluate_episode(model_default, env)
        mean_return_default /= eval_rollouts
        avg_default+=mean_return_default
        if(timesteps_so_far>=0.95*total_timesteps):
            final_default+=mean_return_default

        print(f"Return (Default): {mean_return_default}")
        print(f"Time taken (Default Model): {t2 - t1:.2f} seconds")
        print(f"Timesteps: {timesteps_so_far}, Mean Return: {mean_return_default}")

        t1=time.time()
        # Train the pink noise model
        model_pink.learn(total_timesteps=eval_frequency)
        # timesteps_so_far += eval_frequency
        t2 = time.time()

        # Evaluate the pink noise model
        mean_return_pink = 0.0
        for _ in range(eval_rollouts):
            mean_return_pink += evaluate_episode(model_pink, env)
        mean_return_pink /= eval_rollouts
        avg_pink+=mean_return_pink
        if(timesteps_so_far>=0.95*total_timesteps):
            final_pink+=mean_return_pink

        print(f"Return (Pink): {mean_return_pink}")
        print(f"Time taken (Pink Noise Model): {t2 - t1:.2f} seconds")
        print(f"Timesteps: {timesteps_so_far}, Mean Return: {mean_return_pink}")

        t1=time.time()
        # Train the pink noise model
        model_OU.learn(total_timesteps=eval_frequency)
        # timesteps_so_far += eval_frequency
        t2 = time.time()

        # Evaluate the pink noise model
        mean_return_OU = 0.0
        for _ in range(eval_rollouts):
            mean_return_OU += evaluate_episode(model_OU, env)
        mean_return_OU/= eval_rollouts
        avg_OU+=mean_return_OU
        if(timesteps_so_far>=0.95*total_timesteps):
            final_OU+=mean_return_OU

        print(f"Return (OU): {mean_return_OU}")
        print(f"Time taken (OU Noise Model): {t2 - t1:.2f} seconds")
        print(f"Timesteps: {timesteps_so_far}, Mean Return: {mean_return_OU}")

        timesteps_so_far += eval_frequency

        wandb.log({
            "mean_return_OU": mean_return_OU,
            "mean_return_pink": mean_return_pink,
            "mean_return_default": mean_return_default,
            "timesteps_so_far": timesteps_so_far
        })

    avg_default/=(total_timesteps/eval_frequency)
    avg_pink/=(total_timesteps/eval_frequency)
    avg_OU/=(total_timesteps/eval_frequency)

    final_default/=(0.05*total_timesteps/eval_frequency)
    final_pink/=(0.05*total_timesteps/eval_frequency)
    final_OU/=(0.05*total_timesteps/eval_frequency)

    wandb.log({
        "final_default": final_default,
        "final_pink": final_pink,
        "final_OU": final_OU,
        "avg_default": avg_default,
        "avg_pink": avg_pink,
        "avg_OU": avg_OU
    })

    print("Mean:")
    print(f"White:{avg_default}           Pink:{avg_pink}             OU:{avg_OU}")
    print("Final:")
    print(f"White:{final_default}           Pink:{final_pink}             OU:{final_OU}")
# Out:
# 2024-01-31 07:41:21.843381: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
#
# 2024-01-31 07:41:21.843512: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
#
# 2024-01-31 07:41:21.970989: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#
# /opt/conda/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#
#   warnings.warn(
#
# /opt/conda/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#
#   warnings.warn(
#
# wandb: Currently logged in as: cathedr4l (rl_team_1). Use `wandb login --relogin` to force relogin
#
# wandb: Tracking run with wandb version 0.16.2
#
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20240131_074134-fnkfuh97
#
# wandb: Run `wandb offline` to turn off syncing.
#
# wandb: Syncing run sandy-smoke-44
#
# wandb: ⭐️ View project at https://wandb.ai/rl_team_1/Pinkie
#
# wandb: 🚀 View run at https://wandb.ai/rl_team_1/Pinkie/runs/fnkfuh97
# Return (Default): 32.17231413569819
#
# Time taken (Default Model): 127.98 seconds
#
# Timesteps: 0, Mean Return: 32.17231413569819
#
# Return (Pink): 11.697002003566668
#
# Time taken (Pink Noise Model): 122.81 seconds
#
# Timesteps: 0, Mean Return: 11.697002003566668
#
# Return (OU): 14.235833955091982
#
# Time taken (OU Noise Model): 125.84 seconds
#
# Timesteps: 0, Mean Return: 14.235833955091982
#
# Return (Default): 26.37072504599511
#
# Time taken (Default Model): 121.47 seconds
#
# Timesteps: 10000, Mean Return: 26.37072504599511
#
# Return (Pink): 22.667363252729086
#
# Time taken (Pink Noise Model): 126.14 seconds
#
# Timesteps: 10000, Mean Return: 22.667363252729086
#
# Return (OU): 36.1149053265344
#
# Time taken (OU Noise Model): 121.68 seconds
#
# Timesteps: 10000, Mean Return: 36.1149053265344
#
# Return (Default): 64.72957887443718
#
# Time taken (Default Model): 122.63 seconds
#
# Timesteps: 20000, Mean Return: 64.72957887443718
#
# Return (Pink): 24.51514785623199
#
# Time taken (Pink Noise Model): 126.14 seconds
#
# Timesteps: 20000, Mean Return: 24.51514785623199
#
# Return (OU): 41.36332943449527
#
# Time taken (OU Noise Model): 122.82 seconds
#
# Timesteps: 20000, Mean Return: 41.36332943449527
#
# Return (Default): 75.92737023979456
#
# Time taken (Default Model): 122.98 seconds
#
# Timesteps: 30000, Mean Return: 75.92737023979456
#
# Return (Pink): 60.90330064930661
#
# Time taken (Pink Noise Model): 125.91 seconds
#
# Timesteps: 30000, Mean Return: 60.90330064930661
#
# Return (OU): 55.88115570311
#
# Time taken (OU Noise Model): 120.83 seconds
#
# Timesteps: 30000, Mean Return: 55.88115570311
#
# Return (Default): 128.0431816670689
#
# Time taken (Default Model): 125.84 seconds
#
# Timesteps: 40000, Mean Return: 128.0431816670689
#
# Return (Pink): 87.29399243710559
#
# Time taken (Pink Noise Model): 127.06 seconds
#
# Timesteps: 40000, Mean Return: 87.29399243710559
#
# Return (OU): 79.76604709415678
#
# Time taken (OU Noise Model): 125.83 seconds
#
# Timesteps: 40000, Mean Return: 79.76604709415678
#
# Return (Default): 112.17514812007035
#
# Time taken (Default Model): 123.78 seconds
#
# Timesteps: 50000, Mean Return: 112.17514812007035
#
# Return (Pink): 75.00376114588556
#
# Time taken (Pink Noise Model): 126.36 seconds
#
# Timesteps: 50000, Mean Return: 75.00376114588556
#
# Return (OU): 104.95865351730382
#
# Time taken (OU Noise Model): 128.34 seconds
#
# Timesteps: 50000, Mean Return: 104.95865351730382
#
# Return (Default): 125.06876507771008
#
# Time taken (Default Model): 122.17 seconds
#
# Timesteps: 60000, Mean Return: 125.06876507771008
#
# Return (Pink): 161.37425635548834
#
# Time taken (Pink Noise Model): 124.39 seconds
#
# Timesteps: 60000, Mean Return: 161.37425635548834
#
# Return (OU): 126.85397684113975
#
# Time taken (OU Noise Model): 127.06 seconds
#
# Timesteps: 60000, Mean Return: 126.85397684113975
#
# Return (Default): 208.2200766101339
#
# Time taken (Default Model): 128.54 seconds
#
# Timesteps: 70000, Mean Return: 208.2200766101339
#
# Return (Pink): 180.6288793292914
#
# Time taken (Pink Noise Model): 125.65 seconds
#
# Timesteps: 70000, Mean Return: 180.6288793292914
#
# Return (OU): 88.14524789989153
#
# Time taken (OU Noise Model): 124.18 seconds
#
# Timesteps: 70000, Mean Return: 88.14524789989153
#
# Return (Default): 231.36950011902064
#
# Time taken (Default Model): 119.82 seconds
#
# Timesteps: 80000, Mean Return: 231.36950011902064
#
# Return (Pink): 198.38644415001804
#
# Time taken (Pink Noise Model): 124.40 seconds
#
# Timesteps: 80000, Mean Return: 198.38644415001804
#
# Return (OU): 91.44137071147321
#
# Time taken (OU Noise Model): 127.51 seconds
#
# Timesteps: 80000, Mean Return: 91.44137071147321
#
# Return (Default): 260.7729793529801
#
# Time taken (Default Model): 126.19 seconds
#
# Timesteps: 90000, Mean Return: 260.7729793529801
#
# Return (Pink): 133.59525967033682
#
# Time taken (Pink Noise Model): 123.97 seconds
#
# Timesteps: 90000, Mean Return: 133.59525967033682
#
# Return (OU): 163.9188650856709
#
# Time taken (OU Noise Model): 128.03 seconds
#
# Timesteps: 90000, Mean Return: 163.9188650856709
#
# Return (Default): 227.88407066871923
#
# Time taken (Default Model): 123.22 seconds
#
# Timesteps: 100000, Mean Return: 227.88407066871923
#
# Return (Pink): 166.72389974540607
#
# Time taken (Pink Noise Model): 127.07 seconds
#
# Timesteps: 100000, Mean Return: 166.72389974540607
#
# Return (OU): 282.1097290420816
#
# Time taken (OU Noise Model): 122.44 seconds
#
# Timesteps: 100000, Mean Return: 282.1097290420816
#
# Return (Default): 250.5114242818135
#
# Time taken (Default Model): 127.40 seconds
#
# Timesteps: 110000, Mean Return: 250.5114242818135
#
# Return (Pink): 146.512643918982
#
# Time taken (Pink Noise Model): 125.10 seconds
#
# Timesteps: 110000, Mean Return: 146.512643918982
#
# Return (OU): 221.1616381587043
#
# Time taken (OU Noise Model): 122.50 seconds
#
# Timesteps: 110000, Mean Return: 221.1616381587043
#
# Return (Default): 235.46438795104314
#
# Time taken (Default Model): 124.86 seconds
#
# Timesteps: 120000, Mean Return: 235.46438795104314
#
# Return (Pink): 218.33442121231465
#
# Time taken (Pink Noise Model): 129.94 seconds
#
# Timesteps: 120000, Mean Return: 218.33442121231465
#
# Return (OU): 208.7617335303418
#
# Time taken (OU Noise Model): 124.26 seconds
#
# Timesteps: 120000, Mean Return: 208.7617335303418
#
# Return (Default): 311.25120233120487
#
# Time taken (Default Model): 123.57 seconds
#
# Timesteps: 130000, Mean Return: 311.25120233120487
#
# Return (Pink): 114.87529492828631
#
# Time taken (Pink Noise Model): 127.62 seconds
#
# Timesteps: 130000, Mean Return: 114.87529492828631
#
# Return (OU): 209.46266935394846
#
# Time taken (OU Noise Model): 122.76 seconds
#
# Timesteps: 130000, Mean Return: 209.46266935394846
#
# Return (Default): 243.5260267187951
#
# Time taken (Default Model): 125.14 seconds
#
# Timesteps: 140000, Mean Return: 243.5260267187951
#
# Return (Pink): 225.5783756384356
#
# Time taken (Pink Noise Model): 127.68 seconds
#
# Timesteps: 140000, Mean Return: 225.5783756384356
#
# Return (OU): 290.1444083745422
#
# Time taken (OU Noise Model): 125.10 seconds
#
# Timesteps: 140000, Mean Return: 290.1444083745422
#
# Return (Default): 239.77572943709615
#
# Time taken (Default Model): 125.12 seconds
#
# Timesteps: 150000, Mean Return: 239.77572943709615
#
# Return (Pink): 201.31612753654238
#
# Time taken (Pink Noise Model): 123.48 seconds
#
# Timesteps: 150000, Mean Return: 201.31612753654238
#
# Return (OU): 288.5748936431188
#
# Time taken (OU Noise Model): 127.01 seconds
#
# Timesteps: 150000, Mean Return: 288.5748936431188
#
# Return (Default): 228.51568012883916
#
# Time taken (Default Model): 124.36 seconds
#
# Timesteps: 160000, Mean Return: 228.51568012883916
#
# Return (Pink): 254.21443152333637
#
# Time taken (Pink Noise Model): 125.01 seconds
#
# Timesteps: 160000, Mean Return: 254.21443152333637
#
# Return (OU): 280.3607265113474
#
# Time taken (OU Noise Model): 129.60 seconds
#
# Timesteps: 160000, Mean Return: 280.3607265113474
#
# Return (Default): 342.427569135013
#
# Time taken (Default Model): 122.45 seconds
#
# Timesteps: 170000, Mean Return: 342.427569135013
#
# Return (Pink): 227.1156515187311
#
# Time taken (Pink Noise Model): 126.96 seconds
#
# Timesteps: 170000, Mean Return: 227.1156515187311
#
# Return (OU): 302.13234135913154
#
# Time taken (OU Noise Model): 126.81 seconds
#
# Timesteps: 170000, Mean Return: 302.13234135913154
#
# Return (Default): 382.45133106986907
#
# Time taken (Default Model): 116.69 seconds
#
# Timesteps: 180000, Mean Return: 382.45133106986907
#
# Return (Pink): 226.4696901629994
#
# Time taken (Pink Noise Model): 121.12 seconds
#
# Timesteps: 180000, Mean Return: 226.4696901629994
#
# Return (OU): 315.18014839175714
#
# Time taken (OU Noise Model): 118.73 seconds
#
# Timesteps: 180000, Mean Return: 315.18014839175714
#
# Return (Default): 283.1381482114759
#
# Time taken (Default Model): 118.85 seconds
#
# Timesteps: 190000, Mean Return: 283.1381482114759
#
# Return (Pink): 275.3772152538002
#
# Time taken (Pink Noise Model): 118.82 seconds
#
# Timesteps: 190000, Mean Return: 275.3772152538002
#
# Return (OU): 298.79552073272225
#
# Time taken (OU Noise Model): 117.80 seconds
#
# Timesteps: 190000, Mean Return: 298.79552073272225
#
# Return (Default): 322.63192443481023
#
# Time taken (Default Model): 116.06 seconds
#
# Timesteps: 200000, Mean Return: 322.63192443481023
#
# Return (Pink): 297.4777014855789
#
# Time taken (Pink Noise Model): 122.72 seconds
#
# Timesteps: 200000, Mean Return: 297.4777014855789
#
# Return (OU): 353.10643072170586
#
# Time taken (OU Noise Model): 122.59 seconds
#
# Timesteps: 200000, Mean Return: 353.10643072170586
#
# Return (Default): 384.8079673588562
#
# Time taken (Default Model): 117.62 seconds
#
# Timesteps: 210000, Mean Return: 384.8079673588562
#
# Return (Pink): 293.21656753054464
#
# Time taken (Pink Noise Model): 118.94 seconds
#
# Timesteps: 210000, Mean Return: 293.21656753054464
#
# Return (OU): 284.8558812344405
#
# Time taken (OU Noise Model): 123.68 seconds
#
# Timesteps: 210000, Mean Return: 284.8558812344405
#
# Return (Default): 395.56067996976964
#
# Time taken (Default Model): 120.41 seconds
#
# Timesteps: 220000, Mean Return: 395.56067996976964
#
# Return (Pink): 297.2223774091291
#
# Time taken (Pink Noise Model): 119.33 seconds
#
# Timesteps: 220000, Mean Return: 297.2223774091291
#
# Return (OU): 371.47490691496245
#
# Time taken (OU Noise Model): 126.52 seconds
#
# Timesteps: 220000, Mean Return: 371.47490691496245
#
# Return (Default): 379.065957101589
#
# Time taken (Default Model): 120.62 seconds
#
# Timesteps: 230000, Mean Return: 379.065957101589
#
# Return (Pink): 266.92978078296954
#
# Time taken (Pink Noise Model): 118.35 seconds
#
# Timesteps: 230000, Mean Return: 266.92978078296954
#
# Return (OU): 331.73664336776136
#
# Time taken (OU Noise Model): 123.16 seconds
#
# Timesteps: 230000, Mean Return: 331.73664336776136
#
# Return (Default): 377.4917469088823
#
# Time taken (Default Model): 117.33 seconds
#
# Timesteps: 240000, Mean Return: 377.4917469088823
#
# Return (Pink): 407.54541935730447
#
# Time taken (Pink Noise Model): 118.28 seconds
#
# Timesteps: 240000, Mean Return: 407.54541935730447
#
# Return (OU): 282.6833308981826
#
# Time taken (OU Noise Model): 123.47 seconds
#
# Timesteps: 240000, Mean Return: 282.6833308981826
#
# Return (Default): 403.96124983798336
#
# Time taken (Default Model): 121.73 seconds
#
# Timesteps: 250000, Mean Return: 403.96124983798336
#
# Return (Pink): 399.9502244710343
#
# Time taken (Pink Noise Model): 122.04 seconds
#
# Timesteps: 250000, Mean Return: 399.9502244710343
#
# Return (OU): 328.30358098858085
#
# Time taken (OU Noise Model): 132.23 seconds
#
# Timesteps: 250000, Mean Return: 328.30358098858085
#
# Return (Default): 422.25796208314523
#
# Time taken (Default Model): 127.60 seconds
#
# Timesteps: 260000, Mean Return: 422.25796208314523
#
# Return (Pink): 445.41039272052984
#
# Time taken (Pink Noise Model): 128.35 seconds
#
# Timesteps: 260000, Mean Return: 445.41039272052984
#
# Return (OU): 415.75165307061013
#
# Time taken (OU Noise Model): 126.73 seconds
#
# Timesteps: 260000, Mean Return: 415.75165307061013
#
# Return (Default): 416.8743987924407
#
# Time taken (Default Model): 131.27 seconds
#
# Timesteps: 270000, Mean Return: 416.8743987924407
#
# Return (Pink): 452.1029032065725
#
# Time taken (Pink Noise Model): 130.00 seconds
#
# Timesteps: 270000, Mean Return: 452.1029032065725
#
# Return (OU): 394.54143927282155
#
# Time taken (OU Noise Model): 128.06 seconds
#
# Timesteps: 270000, Mean Return: 394.54143927282155
#
# Return (Default): 437.0584463909706
#
# Time taken (Default Model): 126.89 seconds
#
# Timesteps: 280000, Mean Return: 437.0584463909706
#
# Return (Pink): 441.00219071954245
#
# Time taken (Pink Noise Model): 128.69 seconds
#
# Timesteps: 280000, Mean Return: 441.00219071954245
#
# Return (OU): 405.1099884986324
#
# Time taken (OU Noise Model): 131.88 seconds
#
# Timesteps: 280000, Mean Return: 405.1099884986324
#
# Return (Default): 445.0247424804784
#
# Time taken (Default Model): 124.35 seconds
#
# Timesteps: 290000, Mean Return: 445.0247424804784
#
# Return (Pink): 342.3605004444717
#
# Time taken (Pink Noise Model): 132.61 seconds
#
# Timesteps: 290000, Mean Return: 342.3605004444717
#
# Return (OU): 415.45673033688024
#
# Time taken (OU Noise Model): 127.78 seconds
#
# Timesteps: 290000, Mean Return: 415.45673033688024
#
# Return (Default): 427.2363868883375
#
# Time taken (Default Model): 130.46 seconds
#
# Timesteps: 300000, Mean Return: 427.2363868883375
#
# Return (Pink): 485.21809616066923
#
# Time taken (Pink Noise Model): 129.13 seconds
#
# Timesteps: 300000, Mean Return: 485.21809616066923
#
# Return (OU): 423.12053561008105
#
# Time taken (OU Noise Model): 129.25 seconds
#
# Timesteps: 300000, Mean Return: 423.12053561008105
#
# Return (Default): 431.0186202868466
#
# Time taken (Default Model): 130.26 seconds
#
# Timesteps: 310000, Mean Return: 431.0186202868466
#
# Return (Pink): 502.52060987843214
#
# Time taken (Pink Noise Model): 126.02 seconds
#
# Timesteps: 310000, Mean Return: 502.52060987843214
#
# Return (OU): 415.2214958222602
#
# Time taken (OU Noise Model): 131.58 seconds
#
# Timesteps: 310000, Mean Return: 415.2214958222602
#
# Return (Default): 422.19867241765917
#
# Time taken (Default Model): 132.20 seconds
#
# Timesteps: 320000, Mean Return: 422.19867241765917
#
# Return (Pink): 434.6448077681739
#
# Time taken (Pink Noise Model): 127.02 seconds
#
# Timesteps: 320000, Mean Return: 434.6448077681739
#
# Return (OU): 413.14158356573296
#
# Time taken (OU Noise Model): 126.62 seconds
#
# Timesteps: 320000, Mean Return: 413.14158356573296
#
# Return (Default): 410.2042791979369
#
# Time taken (Default Model): 124.36 seconds
#
# Timesteps: 330000, Mean Return: 410.2042791979369
#
# Return (Pink): 486.5194293647978
#
# Time taken (Pink Noise Model): 125.47 seconds
#
# Timesteps: 330000, Mean Return: 486.5194293647978
#
# Return (OU): 389.9920797634787
#
# Time taken (OU Noise Model): 128.23 seconds
#
# Timesteps: 330000, Mean Return: 389.9920797634787
#
# Return (Default): 437.18618829879244
#
# Time taken (Default Model): 121.37 seconds
#
# Timesteps: 340000, Mean Return: 437.18618829879244
#
# Return (Pink): 429.9770272585214
#
# Time taken (Pink Noise Model): 123.50 seconds
#
# Timesteps: 340000, Mean Return: 429.9770272585214
#
# Return (OU): 188.84489204425373
#
# Time taken (OU Noise Model): 122.61 seconds
#
# Timesteps: 340000, Mean Return: 188.84489204425373
#
# Return (Default): 450.04341252069287
#
# Time taken (Default Model): 118.65 seconds
#
# Timesteps: 350000, Mean Return: 450.04341252069287
#
# Return (Pink): 501.95723697653057
#
# Time taken (Pink Noise Model): 120.04 seconds
#
# Timesteps: 350000, Mean Return: 501.95723697653057
#
# Return (OU): 375.4410307158991
#
# Time taken (OU Noise Model): 120.67 seconds
#
# Timesteps: 350000, Mean Return: 375.4410307158991
#
# Return (Default): 421.89654396184767
#
# Time taken (Default Model): 120.96 seconds
#
# Timesteps: 360000, Mean Return: 421.89654396184767
#
# Return (Pink): 496.2021955454924
#
# Time taken (Pink Noise Model): 119.24 seconds
#
# Timesteps: 360000, Mean Return: 496.2021955454924
#
# Return (OU): 382.0596234836662
#
# Time taken (OU Noise Model): 119.26 seconds
#
# Timesteps: 360000, Mean Return: 382.0596234836662
#
# Return (Default): 429.0247756813207
#
# Time taken (Default Model): 120.04 seconds
#
# Timesteps: 370000, Mean Return: 429.0247756813207
#
# Return (Pink): 473.1507894642189
#
# Time taken (Pink Noise Model): 120.35 seconds
#
# Timesteps: 370000, Mean Return: 473.1507894642189
#
# Return (OU): 344.3633487651059
#
# Time taken (OU Noise Model): 117.66 seconds
#
# Timesteps: 370000, Mean Return: 344.3633487651059
#
# Return (Default): 442.13655707185234
#
# Time taken (Default Model): 120.16 seconds
#
# Timesteps: 380000, Mean Return: 442.13655707185234
#
# Return (Pink): 510.03759528066
#
# Time taken (Pink Noise Model): 121.77 seconds
#
# Timesteps: 380000, Mean Return: 510.03759528066
#
# Return (OU): 476.96968415506507
#
# Time taken (OU Noise Model): 117.79 seconds
#
# Timesteps: 380000, Mean Return: 476.96968415506507
#
# Return (Default): 453.4454838112897
#
# Time taken (Default Model): 120.02 seconds
#
# Timesteps: 390000, Mean Return: 453.4454838112897
#
# Return (Pink): 564.275503445126
#
# Time taken (Pink Noise Model): 118.12 seconds
#
# Timesteps: 390000, Mean Return: 564.275503445126
#
# Return (OU): 404.1643209073732
#
# Time taken (OU Noise Model): 120.04 seconds
#
# Timesteps: 390000, Mean Return: 404.1643209073732
#
# Return (Default): 475.2616775839937
#
# Time taken (Default Model): 119.05 seconds
#
# Timesteps: 400000, Mean Return: 475.2616775839937
#
# Return (Pink): 547.890650834587
#
# Time taken (Pink Noise Model): 118.52 seconds
#
# Timesteps: 400000, Mean Return: 547.890650834587
#
# Return (OU): 310.4548957887917
#
# Time taken (OU Noise Model): 121.37 seconds
#
# Timesteps: 400000, Mean Return: 310.4548957887917
#
# Return (Default): 473.5823661639065
#
# Time taken (Default Model): 117.75 seconds
#
# Timesteps: 410000, Mean Return: 473.5823661639065
#
# Return (Pink): 543.2943346111664
#
# Time taken (Pink Noise Model): 118.96 seconds
#
# Timesteps: 410000, Mean Return: 543.2943346111664
#
# Return (OU): 441.06885711163886
#
# Time taken (OU Noise Model): 122.88 seconds
#
# Timesteps: 410000, Mean Return: 441.06885711163886
#
# Return (Default): 470.32053238886255
#
# Time taken (Default Model): 118.80 seconds
#
# Timesteps: 420000, Mean Return: 470.32053238886255
#
# Return (Pink): 544.4394507438576
#
# Time taken (Pink Noise Model): 121.06 seconds
#
# Timesteps: 420000, Mean Return: 544.4394507438576
#
# Return (OU): 483.58053056812577
#
# Time taken (OU Noise Model): 124.99 seconds
#
# Timesteps: 420000, Mean Return: 483.58053056812577
#
# Return (Default): 479.85499259259893
#
# Time taken (Default Model): 121.96 seconds
#
# Timesteps: 430000, Mean Return: 479.85499259259893
#
# Return (Pink): 525.894387918122
#
# Time taken (Pink Noise Model): 126.38 seconds
#
# Timesteps: 430000, Mean Return: 525.894387918122
#
# Return (OU): 482.5932926717117
#
# Time taken (OU Noise Model): 126.34 seconds
#
# Timesteps: 430000, Mean Return: 482.5932926717117
#
# Return (Default): 469.8948536680411
#
# Time taken (Default Model): 122.59 seconds
#
# Timesteps: 440000, Mean Return: 469.8948536680411
#
# Return (Pink): 565.505311594932
#
# Time taken (Pink Noise Model): 126.58 seconds
#
# Timesteps: 440000, Mean Return: 565.505311594932
#
# Return (OU): 483.701730111722
#
# Time taken (OU Noise Model): 125.47 seconds
#
# Timesteps: 440000, Mean Return: 483.701730111722
#
# Return (Default): 485.1897853802516
#
# Time taken (Default Model): 121.16 seconds
#
# Timesteps: 450000, Mean Return: 485.1897853802516
#
# Return (Pink): 569.2119005469733
#
# Time taken (Pink Noise Model): 127.40 seconds
#
# Timesteps: 450000, Mean Return: 569.2119005469733
#
# Return (OU): 453.8293115504841
#
# Time taken (OU Noise Model): 129.96 seconds
#
# Timesteps: 450000, Mean Return: 453.8293115504841
#
# Return (Default): 493.29363392804487
#
# Time taken (Default Model): 123.63 seconds
#
# Timesteps: 460000, Mean Return: 493.29363392804487
#
# Return (Pink): 539.0761154913442
#
# Time taken (Pink Noise Model): 125.51 seconds
#
# Timesteps: 460000, Mean Return: 539.0761154913442
#
# Return (OU): 462.92982579882494
#
# Time taken (OU Noise Model): 125.22 seconds
#
# Timesteps: 460000, Mean Return: 462.92982579882494
#
# Return (Default): 449.0350594850106
#
# Time taken (Default Model): 121.39 seconds
#
# Timesteps: 470000, Mean Return: 449.0350594850106
#
# Return (Pink): 537.3902319887801
#
# Time taken (Pink Noise Model): 125.71 seconds
#
# Timesteps: 470000, Mean Return: 537.3902319887801
#
# Return (OU): 477.6581643433963
#
# Time taken (OU Noise Model): 123.73 seconds
#
# Timesteps: 470000, Mean Return: 477.6581643433963
#
# Return (Default): 509.1729933035438
#
# Time taken (Default Model): 121.64 seconds
#
# Timesteps: 480000, Mean Return: 509.1729933035438
#
# Return (Pink): 550.8522558755747
#
# Time taken (Pink Noise Model): 127.17 seconds
#
# Timesteps: 480000, Mean Return: 550.8522558755747
#
# Return (OU): 471.1467431267605
#
# Time taken (OU Noise Model): 126.80 seconds
#
# Timesteps: 480000, Mean Return: 471.1467431267605
#
# Return (Default): 433.5466382856156
#
# Time taken (Default Model): 121.51 seconds
#
# Timesteps: 490000, Mean Return: 433.5466382856156
#
# Return (Pink): 578.6269046673093
#
# Time taken (Pink Noise Model): 123.79 seconds
#
# Timesteps: 490000, Mean Return: 578.6269046673093
#
# Return (OU): 489.6620964984281
#
# Time taken (OU Noise Model): 124.12 seconds
#
# Timesteps: 490000, Mean Return: 489.6620964984281
#
# Return (Default): 533.2875299539704
#
# Time taken (Default Model): 120.90 seconds
#
# Timesteps: 500000, Mean Return: 533.2875299539704
#
# Return (Pink): 579.147488281169
#
# Time taken (Pink Noise Model): 119.18 seconds
#
# Timesteps: 500000, Mean Return: 579.147488281169
#
# Return (OU): 507.35930585335666
#
# Time taken (OU Noise Model): 120.32 seconds
#
# Timesteps: 500000, Mean Return: 507.35930585335666
#
# Return (Default): 523.0083845720106
#
# Time taken (Default Model): 116.84 seconds
#
# Timesteps: 510000, Mean Return: 523.0083845720106
#
# Return (Pink): 584.6174346946576
#
# Time taken (Pink Noise Model): 118.93 seconds
#
# Timesteps: 510000, Mean Return: 584.6174346946576
#
# Return (OU): 536.0120989562323
#
# Time taken (OU Noise Model): 119.36 seconds
#
# Timesteps: 510000, Mean Return: 536.0120989562323
#
# Return (Default): 517.4833521307006
#
# Time taken (Default Model): 116.19 seconds
#
# Timesteps: 520000, Mean Return: 517.4833521307006
#
# Return (Pink): 557.5219279834809
#
# Time taken (Pink Noise Model): 118.54 seconds
#
# Timesteps: 520000, Mean Return: 557.5219279834809
#
# Return (OU): 565.1261609060901
#
# Time taken (OU Noise Model): 117.91 seconds
#
# Timesteps: 520000, Mean Return: 565.1261609060901
#
# Return (Default): 540.1712190587724
#
# Time taken (Default Model): 117.37 seconds
#
# Timesteps: 530000, Mean Return: 540.1712190587724
#
# Return (Pink): 565.0176971282411
#
# Time taken (Pink Noise Model): 119.77 seconds
#
# Timesteps: 530000, Mean Return: 565.0176971282411
#
# Return (OU): 534.3792839533905
#
# Time taken (OU Noise Model): 118.00 seconds
#
# Timesteps: 530000, Mean Return: 534.3792839533905
#
# Return (Default): 515.2043787621528
#
# Time taken (Default Model): 116.27 seconds
#
# Timesteps: 540000, Mean Return: 515.2043787621528
#
# Return (Pink): 535.5464114243057
#
# Time taken (Pink Noise Model): 120.16 seconds
#
# Timesteps: 540000, Mean Return: 535.5464114243057
#
# Return (OU): 562.2292104567841
#
# Time taken (OU Noise Model): 119.86 seconds
#
# Timesteps: 540000, Mean Return: 562.2292104567841
#
# Return (Default): 508.8657364506439
#
# Time taken (Default Model): 117.51 seconds
#
# Timesteps: 550000, Mean Return: 508.8657364506439
#
# Return (Pink): 594.2535765711466
#
# Time taken (Pink Noise Model): 118.67 seconds
#
# Timesteps: 550000, Mean Return: 594.2535765711466
#
# Return (OU): 498.9512998389855
#
# Time taken (OU Noise Model): 118.46 seconds
#
# Timesteps: 550000, Mean Return: 498.9512998389855
#
# Return (Default): 494.28175885826386
#
# Time taken (Default Model): 116.95 seconds
#
# Timesteps: 560000, Mean Return: 494.28175885826386
#
# Return (Pink): 581.9899893822669
#
# Time taken (Pink Noise Model): 118.72 seconds
#
# Timesteps: 560000, Mean Return: 581.9899893822669
#
# Return (OU): 530.6307740653883
#
# Time taken (OU Noise Model): 119.92 seconds
#
# Timesteps: 560000, Mean Return: 530.6307740653883
#
# Return (Default): 513.6141926114618
#
# Time taken (Default Model): 118.55 seconds
#
# Timesteps: 570000, Mean Return: 513.6141926114618
#
# Return (Pink): 570.0927719047138
#
# Time taken (Pink Noise Model): 119.38 seconds
#
# Timesteps: 570000, Mean Return: 570.0927719047138
#
# Return (OU): 534.1622816380468
#
# Time taken (OU Noise Model): 118.54 seconds
#
# Timesteps: 570000, Mean Return: 534.1622816380468
#
# Return (Default): 516.34027742277
#
# Time taken (Default Model): 116.22 seconds
#
# Timesteps: 580000, Mean Return: 516.34027742277
#
# Return (Pink): 607.7970663763683
#
# Time taken (Pink Noise Model): 119.89 seconds
#
# Timesteps: 580000, Mean Return: 607.7970663763683
#
# Return (OU): 513.930688739905
#
# Time taken (OU Noise Model): 119.51 seconds
#
# Timesteps: 580000, Mean Return: 513.930688739905
#
# Return (Default): 499.24339003785724
#
# Time taken (Default Model): 116.25 seconds
#
# Timesteps: 590000, Mean Return: 499.24339003785724
#
# Return (Pink): 594.9608821285108
#
# Time taken (Pink Noise Model): 119.78 seconds
#
# Timesteps: 590000, Mean Return: 594.9608821285108
#
# Return (OU): 543.0235007626119
#
# Time taken (OU Noise Model): 119.36 seconds
#
# Timesteps: 590000, Mean Return: 543.0235007626119
#
# Return (Default): 532.4044810026362
#
# Time taken (Default Model): 115.89 seconds
#
# Timesteps: 600000, Mean Return: 532.4044810026362
#
# Return (Pink): 612.7513108606763
#
# Time taken (Pink Noise Model): 119.08 seconds
#
# Timesteps: 600000, Mean Return: 612.7513108606763
#
# Return (OU): 563.0435478336733
#
# Time taken (OU Noise Model): 117.73 seconds
#
# Timesteps: 600000, Mean Return: 563.0435478336733
#
# Return (Default): 555.6510247128979
#
# Time taken (Default Model): 117.76 seconds
#
# Timesteps: 610000, Mean Return: 555.6510247128979
#
# Return (Pink): 568.8340208778925
#
# Time taken (Pink Noise Model): 118.91 seconds
#
# Timesteps: 610000, Mean Return: 568.8340208778925
#
# Return (OU): 597.6393657433329
#
# Time taken (OU Noise Model): 118.67 seconds
#
# Timesteps: 610000, Mean Return: 597.6393657433329
#
# Return (Default): 527.3731854622432
#
# Time taken (Default Model): 116.36 seconds
#
# Timesteps: 620000, Mean Return: 527.3731854622432
#
# Return (Pink): 597.2650137455818
#
# Time taken (Pink Noise Model): 117.75 seconds
#
# Timesteps: 620000, Mean Return: 597.2650137455818
#
# Return (OU): 536.830520663748
#
# Time taken (OU Noise Model): 118.80 seconds
#
# Timesteps: 620000, Mean Return: 536.830520663748
#
# Return (Default): 337.2754279664306
#
# Time taken (Default Model): 119.76 seconds
#
# Timesteps: 630000, Mean Return: 337.2754279664306
#
# Return (Pink): 572.515408509357
#
# Time taken (Pink Noise Model): 120.07 seconds
#
# Timesteps: 630000, Mean Return: 572.515408509357
#
# Return (OU): 550.9610380335155
#
# Time taken (OU Noise Model): 118.16 seconds
#
# Timesteps: 630000, Mean Return: 550.9610380335155
#
# Return (Default): 370.70252017697055
#
# Time taken (Default Model): 117.54 seconds
#
# Timesteps: 640000, Mean Return: 370.70252017697055
#
# Return (Pink): 598.5010527618267
#
# Time taken (Pink Noise Model): 118.47 seconds
#
# Timesteps: 640000, Mean Return: 598.5010527618267
#
# Return (OU): 582.4695512696795
#
# Time taken (OU Noise Model): 119.13 seconds
#
# Timesteps: 640000, Mean Return: 582.4695512696795
#
# Return (Default): 527.9891720467411
#
# Time taken (Default Model): 116.97 seconds
#
# Timesteps: 650000, Mean Return: 527.9891720467411
#
# Return (Pink): 606.4115795367725
#
# Time taken (Pink Noise Model): 119.37 seconds
#
# Timesteps: 650000, Mean Return: 606.4115795367725
#
# Return (OU): 588.191111457162
#
# Time taken (OU Noise Model): 118.89 seconds
#
# Timesteps: 650000, Mean Return: 588.191111457162
#
# Return (Default): 549.9303217264071
#
# Time taken (Default Model): 116.26 seconds
#
# Timesteps: 660000, Mean Return: 549.9303217264071
#
# Return (Pink): 603.8257274222772
#
# Time taken (Pink Noise Model): 118.09 seconds
#
# Timesteps: 660000, Mean Return: 603.8257274222772
#
# Return (OU): 587.1406223126571
#
# Time taken (OU Noise Model): 120.02 seconds
#
# Timesteps: 660000, Mean Return: 587.1406223126571
#
# Return (Default): 515.2486958117927
#
# Time taken (Default Model): 118.91 seconds
#
# Timesteps: 670000, Mean Return: 515.2486958117927
#
# Return (Pink): 608.8165849471782
#
# Time taken (Pink Noise Model): 118.49 seconds
#
# Timesteps: 670000, Mean Return: 608.8165849471782
#
# Return (OU): 558.5927836024628
#
# Time taken (OU Noise Model): 118.11 seconds
#
# Timesteps: 670000, Mean Return: 558.5927836024628
#
# Return (Default): 560.7784561566568
#
# Time taken (Default Model): 118.57 seconds
#
# Timesteps: 680000, Mean Return: 560.7784561566568
#
# Return (Pink): 596.4235154327051
#
# Time taken (Pink Noise Model): 120.63 seconds
#
# Timesteps: 680000, Mean Return: 596.4235154327051
#
# Return (OU): 572.5236647713118
#
# Time taken (OU Noise Model): 117.62 seconds
#
# Timesteps: 680000, Mean Return: 572.5236647713118
#
# Return (Default): 579.4375740617512
#
# Time taken (Default Model): 117.52 seconds
#
# Timesteps: 690000, Mean Return: 579.4375740617512
#
# Return (Pink): 575.0636168297522
#
# Time taken (Pink Noise Model): 122.31 seconds
#
# Timesteps: 690000, Mean Return: 575.0636168297522
#
# Return (OU): 559.6579859767093
#
# Time taken (OU Noise Model): 117.90 seconds
#
# Timesteps: 690000, Mean Return: 559.6579859767093
#
# Return (Default): 567.2347683187259
#
# Time taken (Default Model): 117.26 seconds
#
# Timesteps: 700000, Mean Return: 567.2347683187259
#
# Return (Pink): 566.2597231091353
#
# Time taken (Pink Noise Model): 118.01 seconds
#
# Timesteps: 700000, Mean Return: 566.2597231091353
#
# Return (OU): 573.914683502371
#
# Time taken (OU Noise Model): 118.58 seconds
#
# Timesteps: 700000, Mean Return: 573.914683502371
#
# Return (Default): 566.1548729764514
#
# Time taken (Default Model): 116.18 seconds
#
# Timesteps: 710000, Mean Return: 566.1548729764514
#
# Return (Pink): 588.0835606278318
#
# Time taken (Pink Noise Model): 117.61 seconds
#
# Timesteps: 710000, Mean Return: 588.0835606278318
#
# Return (OU): 581.2507128998355
#
# Time taken (OU Noise Model): 118.59 seconds
#
# Timesteps: 710000, Mean Return: 581.2507128998355
#
# Return (Default): 582.2268184371856
#
# Time taken (Default Model): 118.26 seconds
#
# Timesteps: 720000, Mean Return: 582.2268184371856
#
# Return (Pink): 590.0821629864109
#
# Time taken (Pink Noise Model): 119.13 seconds
#
# Timesteps: 720000, Mean Return: 590.0821629864109
#
# Return (OU): 559.2983062190399
#
# Time taken (OU Noise Model): 119.15 seconds
#
# Timesteps: 720000, Mean Return: 559.2983062190399
#
# Return (Default): 561.3075477727358
#
# Time taken (Default Model): 117.00 seconds
#
# Timesteps: 730000, Mean Return: 561.3075477727358
#
# Return (Pink): 579.3910194510038
#
# Time taken (Pink Noise Model): 117.97 seconds
#
# Timesteps: 730000, Mean Return: 579.3910194510038
#
# Return (OU): 562.4587458311765
#
# Time taken (OU Noise Model): 118.59 seconds
#
# Timesteps: 730000, Mean Return: 562.4587458311765
#
# Return (Default): 587.130523872304
#
# Time taken (Default Model): 116.37 seconds
#
# Timesteps: 740000, Mean Return: 587.130523872304
#
# Return (Pink): 581.8260162692752
#
# Time taken (Pink Noise Model): 119.47 seconds
#
# Timesteps: 740000, Mean Return: 581.8260162692752
#
# Return (OU): 574.4906108397992
#
# Time taken (OU Noise Model): 118.07 seconds
#
# Timesteps: 740000, Mean Return: 574.4906108397992
#
# Return (Default): 570.5751419029971
#
# Time taken (Default Model): 117.36 seconds
#
# Timesteps: 750000, Mean Return: 570.5751419029971
#
# Return (Pink): 596.1127716730268
#
# Time taken (Pink Noise Model): 119.58 seconds
#
# Timesteps: 750000, Mean Return: 596.1127716730268
#
# Return (OU): 568.0524612830588
#
# Time taken (OU Noise Model): 117.85 seconds
#
# Timesteps: 750000, Mean Return: 568.0524612830588
#
# Return (Default): 568.4735259746702
#
# Time taken (Default Model): 118.66 seconds
#
# Timesteps: 760000, Mean Return: 568.4735259746702
#
# Return (Pink): 596.0945917276143
#
# Time taken (Pink Noise Model): 118.76 seconds
#
# Timesteps: 760000, Mean Return: 596.0945917276143
#
# Return (OU): 549.4528215040849
#
# Time taken (OU Noise Model): 119.56 seconds
#
# Timesteps: 760000, Mean Return: 549.4528215040849
#
# Return (Default): 585.3298367916666
#
# Time taken (Default Model): 119.80 seconds
#
# Timesteps: 770000, Mean Return: 585.3298367916666
#
# Return (Pink): 600.1089516271128
#
# Time taken (Pink Noise Model): 119.15 seconds
#
# Timesteps: 770000, Mean Return: 600.1089516271128
#
# Return (OU): 571.0973465788313
#
# Time taken (OU Noise Model): 120.92 seconds
#
# Timesteps: 770000, Mean Return: 571.0973465788313
#
# Return (Default): 552.1117274351893
#
# Time taken (Default Model): 118.59 seconds
#
# Timesteps: 780000, Mean Return: 552.1117274351893
#
# Return (Pink): 615.0889029416737
#
# Time taken (Pink Noise Model): 119.30 seconds
#
# Timesteps: 780000, Mean Return: 615.0889029416737
#
# Return (OU): 590.9691282723363
#
# Time taken (OU Noise Model): 120.76 seconds
#
# Timesteps: 780000, Mean Return: 590.9691282723363
#
# Return (Default): 589.7700611169655
#
# Time taken (Default Model): 118.25 seconds
#
# Timesteps: 790000, Mean Return: 589.7700611169655
#
# Return (Pink): 634.3704631736447
#
# Time taken (Pink Noise Model): 118.66 seconds
#
# Timesteps: 790000, Mean Return: 634.3704631736447
#
# Return (OU): 543.2647129302738
#
# Time taken (OU Noise Model): 119.06 seconds
#
# Timesteps: 790000, Mean Return: 543.2647129302738
#
# Return (Default): 562.1907595934515
#
# Time taken (Default Model): 118.34 seconds
#
# Timesteps: 800000, Mean Return: 562.1907595934515
#
# Return (Pink): 615.0671959660692
#
# Time taken (Pink Noise Model): 119.89 seconds
#
# Timesteps: 800000, Mean Return: 615.0671959660692
#
# Return (OU): 574.9257682756108
#
# Time taken (OU Noise Model): 118.65 seconds
#
# Timesteps: 800000, Mean Return: 574.9257682756108
#
# Return (Default): 547.986632297924
#
# Time taken (Default Model): 119.28 seconds
#
# Timesteps: 810000, Mean Return: 547.986632297924
#
# Return (Pink): 622.280170867802
#
# Time taken (Pink Noise Model): 120.64 seconds
#
# Timesteps: 810000, Mean Return: 622.280170867802
#
# Return (OU): 575.8399048482954
#
# Time taken (OU Noise Model): 119.61 seconds
#
# Timesteps: 810000, Mean Return: 575.8399048482954
#
# Return (Default): 550.3122332125256
#
# Time taken (Default Model): 117.45 seconds
#
# Timesteps: 820000, Mean Return: 550.3122332125256
#
# Return (Pink): 522.7512671562868
#
# Time taken (Pink Noise Model): 120.00 seconds
#
# Timesteps: 820000, Mean Return: 522.7512671562868
#
# Return (OU): 588.9736551899863
#
# Time taken (OU Noise Model): 118.40 seconds
#
# Timesteps: 820000, Mean Return: 588.9736551899863
#
# Return (Default): 562.3561708808505
#
# Time taken (Default Model): 118.63 seconds
#
# Timesteps: 830000, Mean Return: 562.3561708808505
#
# Return (Pink): 635.212757521415
#
# Time taken (Pink Noise Model): 119.55 seconds
#
# Timesteps: 830000, Mean Return: 635.212757521415
#
# Return (OU): 578.4001443037668
#
# Time taken (OU Noise Model): 119.16 seconds
#
# Timesteps: 830000, Mean Return: 578.4001443037668
#
# Return (Default): 554.7712155780707
#
# Time taken (Default Model): 116.41 seconds
#
# Timesteps: 840000, Mean Return: 554.7712155780707
#
# Return (Pink): 635.1927538517833
#
# Time taken (Pink Noise Model): 119.95 seconds
#
# Timesteps: 840000, Mean Return: 635.1927538517833
#
# Return (OU): 525.5773986762873
#
# Time taken (OU Noise Model): 120.41 seconds
#
# Timesteps: 840000, Mean Return: 525.5773986762873
#
# Return (Default): 616.9043095838249
#
# Time taken (Default Model): 117.25 seconds
#
# Timesteps: 850000, Mean Return: 616.9043095838249
#
# Return (Pink): 599.2781482150391
#
# Time taken (Pink Noise Model): 119.58 seconds
#
# Timesteps: 850000, Mean Return: 599.2781482150391
#
# Return (OU): 567.5667591322507
#
# Time taken (OU Noise Model): 118.43 seconds
#
# Timesteps: 850000, Mean Return: 567.5667591322507
#
# Return (Default): 596.3983683396084
#
# Time taken (Default Model): 117.87 seconds
#
# Timesteps: 860000, Mean Return: 596.3983683396084
#
# Return (Pink): 622.5512044447825
#
# Time taken (Pink Noise Model): 119.52 seconds
#
# Timesteps: 860000, Mean Return: 622.5512044447825
#
# Return (OU): 587.436735280181
#
# Time taken (OU Noise Model): 119.83 seconds
#
# Timesteps: 860000, Mean Return: 587.436735280181
#
# Return (Default): 595.9919959495949
#
# Time taken (Default Model): 117.40 seconds
#
# Timesteps: 870000, Mean Return: 595.9919959495949
#
# Return (Pink): 598.1011436059047
#
# Time taken (Pink Noise Model): 119.22 seconds
#
# Timesteps: 870000, Mean Return: 598.1011436059047
#
# Return (OU): 578.2172655864181
#
# Time taken (OU Noise Model): 119.01 seconds
#
# Timesteps: 870000, Mean Return: 578.2172655864181
#
# Return (Default): 586.5463372586149
#
# Time taken (Default Model): 117.97 seconds
#
# Timesteps: 880000, Mean Return: 586.5463372586149
#
# Return (Pink): 645.5570944311673
#
# Time taken (Pink Noise Model): 119.60 seconds
#
# Timesteps: 880000, Mean Return: 645.5570944311673
#
# Return (OU): 568.1609517572697
#
# Time taken (OU Noise Model): 119.20 seconds
#
# Timesteps: 880000, Mean Return: 568.1609517572697
#
# Return (Default): 602.7413293973323
#
# Time taken (Default Model): 117.54 seconds
#
# Timesteps: 890000, Mean Return: 602.7413293973323
#
# Return (Pink): 637.7463506773303
#
# Time taken (Pink Noise Model): 118.11 seconds
#
# Timesteps: 890000, Mean Return: 637.7463506773303
#
# Return (OU): 540.6677519416814
#
# Time taken (OU Noise Model): 119.21 seconds
#
# Timesteps: 890000, Mean Return: 540.6677519416814
#
# Return (Default): 613.5694623799419
#
# Time taken (Default Model): 118.51 seconds
#
# Timesteps: 900000, Mean Return: 613.5694623799419
#
# Return (Pink): 591.8158835271273
#
# Time taken (Pink Noise Model): 119.04 seconds
#
# Timesteps: 900000, Mean Return: 591.8158835271273
#
# Return (OU): 595.9866146602697
#
# Time taken (OU Noise Model): 118.74 seconds
#
# Timesteps: 900000, Mean Return: 595.9866146602697
#
# Return (Default): 579.1847985227029
#
# Time taken (Default Model): 117.14 seconds
#
# Timesteps: 910000, Mean Return: 579.1847985227029
#
# Return (Pink): 614.1475964906768
#
# Time taken (Pink Noise Model): 117.48 seconds
#
# Timesteps: 910000, Mean Return: 614.1475964906768
#
# Return (OU): 572.2891264655603
#
# Time taken (OU Noise Model): 119.06 seconds
#
# Timesteps: 910000, Mean Return: 572.2891264655603
#
# Return (Default): 604.4833210030932
#
# Time taken (Default Model): 117.60 seconds
#
# Timesteps: 920000, Mean Return: 604.4833210030932
#
# Return (Pink): 662.7966654545628
#
# Time taken (Pink Noise Model): 117.67 seconds
#
# Timesteps: 920000, Mean Return: 662.7966654545628
#
# Return (OU): 569.0881024910218
#
# Time taken (OU Noise Model): 119.52 seconds
#
# Timesteps: 920000, Mean Return: 569.0881024910218
#
# Return (Default): 607.7909316452217
#
# Time taken (Default Model): 118.23 seconds
#
# Timesteps: 930000, Mean Return: 607.7909316452217
#
# Return (Pink): 665.4053055669663
#
# Time taken (Pink Noise Model): 117.84 seconds
#
# Timesteps: 930000, Mean Return: 665.4053055669663
#
# Return (OU): 567.1826752496162
#
# Time taken (OU Noise Model): 119.35 seconds
#
# Timesteps: 930000, Mean Return: 567.1826752496162
#
# Return (Default): 586.6057039050627
#
# Time taken (Default Model): 117.61 seconds
#
# Timesteps: 940000, Mean Return: 586.6057039050627
#
# Return (Pink): 598.5357294259913
#
# Time taken (Pink Noise Model): 117.64 seconds
#
# Timesteps: 940000, Mean Return: 598.5357294259913
#
# Return (OU): 604.6110381160267
#
# Time taken (OU Noise Model): 119.05 seconds
#
# Timesteps: 940000, Mean Return: 604.6110381160267
#
# Return (Default): 588.7047933183337
#
# Time taken (Default Model): 117.19 seconds
#
# Timesteps: 950000, Mean Return: 588.7047933183337
#
# Return (Pink): 674.4781342901072
#
# Time taken (Pink Noise Model): 116.85 seconds
#
# Timesteps: 950000, Mean Return: 674.4781342901072
#
# Return (OU): 598.808156982167
#
# Time taken (OU Noise Model): 116.89 seconds
#
# Timesteps: 950000, Mean Return: 598.808156982167
#
# Return (Default): 513.6236113773901
#
# Time taken (Default Model): 115.80 seconds
#
# Timesteps: 960000, Mean Return: 513.6236113773901
#
# Return (Pink): 661.6111549988246
#
# Time taken (Pink Noise Model): 117.26 seconds
#
# Timesteps: 960000, Mean Return: 661.6111549988246
#
# Return (OU): 599.0469995774808
#
# Time taken (OU Noise Model): 117.20 seconds
#
# Timesteps: 960000, Mean Return: 599.0469995774808
#
# Return (Default): 621.9437426295191
#
# Time taken (Default Model): 116.60 seconds
#
# Timesteps: 970000, Mean Return: 621.9437426295191
#
# Return (Pink): 633.1432705848194
#
# Time taken (Pink Noise Model): 117.60 seconds
#
# Timesteps: 970000, Mean Return: 633.1432705848194
#
# Return (OU): 608.3900924514536
#
# Time taken (OU Noise Model): 117.45 seconds
#
# Timesteps: 970000, Mean Return: 608.3900924514536
#
# Return (Default): 567.2909361927066
#
# Time taken (Default Model): 115.62 seconds
#
# Timesteps: 980000, Mean Return: 567.2909361927066
#
# Return (Pink): 647.1113996011647
#
# Time taken (Pink Noise Model): 117.52 seconds
#
# Timesteps: 980000, Mean Return: 647.1113996011647
#
# Return (OU): 518.563619015403
#
# Time taken (OU Noise Model): 117.43 seconds
#
# Timesteps: 980000, Mean Return: 518.563619015403
#
# Return (Default): 602.1846311994518
#
# Time taken (Default Model): 115.58 seconds
#
# Timesteps: 990000, Mean Return: 602.1846311994518
#
# Return (Pink): 657.1713807649423
#
# Time taken (Pink Noise Model): 117.99 seconds
#
# Timesteps: 990000, Mean Return: 657.1713807649423
#
# Return (OU): 444.3897109198101
#
# Time taken (OU Noise Model): 119.05 seconds
#
# Timesteps: 990000, Mean Return: 444.3897109198101
#
# Mean:
#
# White:446.6826092529938           Pink:472.412118996601             OU:435.13554619990333
#
# Final:
#
# White:578.7495429434802           Pink:654.7030680479717             OU:553.839715789263

# %%
env = DMSuiteEnv("cartpole","balance_sparse")
env = DMSuiteEnv("cartpole","swingup_sparse")
env = DMSuiteEnv("ball_in_cup","catch")
env = DMSuiteEnv("hopper","hop")
env = DMSuiteEnv("walker","run")
env = DMSuiteEnv("reacher","hard")
env = DMSuiteEnv("pendulum","swingup")
# Out:
# OrderedDict([('position', Array(shape=(3,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(2,), dtype=dtype('float64'), name='velocity'))])
#
# Dict('position': Box(-inf, inf, (3,), float64), 'velocity': Box(-inf, inf, (2,), float64))
#
# ________________________
#
# BoundedArray(shape=(1,), dtype=dtype('float64'), name=None, minimum=[-1.], maximum=[1.])
#
# Box(-1.0, 1.0, (1,), float64)
#
# OrderedDict([('position', Array(shape=(3,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(2,), dtype=dtype('float64'), name='velocity'))])
#
# Dict('position': Box(-inf, inf, (3,), float64), 'velocity': Box(-inf, inf, (2,), float64))
#
# ________________________
#
# BoundedArray(shape=(1,), dtype=dtype('float64'), name=None, minimum=[-1.], maximum=[1.])
#
# Box(-1.0, 1.0, (1,), float64)
#
# OrderedDict([('position', Array(shape=(4,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(4,), dtype=dtype('float64'), name='velocity'))])
#
# Dict('position': Box(-inf, inf, (4,), float64), 'velocity': Box(-inf, inf, (4,), float64))
#
# ________________________
#
# BoundedArray(shape=(2,), dtype=dtype('float64'), name=None, minimum=[-1. -1.], maximum=[1. 1.])
#
# Box(-1.0, 1.0, (2,), float64)
#
# OrderedDict([('position', Array(shape=(6,), dtype=dtype('float64'), name='position')), ('velocity', Array(shape=(7,), dtype=dtype('float64'), name='velocity')), ('touch', Array(shape=(2,), dtype=dtype('float64'), name='touch'))])
#
# Dict('position': Box(-inf, inf, (6,), float64), 'touch': Box(-inf, inf, (2,), float64), 'velocity': Box(-inf, inf, (7,), float64))
#
# ________________________
#
# BoundedArray(shape=(4,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1.], maximum=[1. 1. 1. 1.])
#
# Box(-1.0, 1.0, (4,), float64)
#
# OrderedDict([('orientations', Array(shape=(14,), dtype=dtype('float64'), name='orientations')), ('height', Array(shape=(), dtype=dtype('float64'), name='height')), ('velocity', Array(shape=(9,), dtype=dtype('float64'), name='velocity'))])
#
# Dict('height': Box(-inf, inf, (), float64), 'orientations': Box(-inf, inf, (14,), float64), 'velocity': Box(-inf, inf, (9,), float64))
#
# ________________________
#
# BoundedArray(shape=(6,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1. 1.])
#
# Box(-1.0, 1.0, (6,), float64)
#
# OrderedDict([('position', Array(shape=(2,), dtype=dtype('float64'), name='position')), ('to_target', Array(shape=(2,), dtype=dtype('float64'), name='to_target')), ('velocity', Array(shape=(2,), dtype=dtype('float64'), name='velocity'))])
#
# Dict('position': Box(-inf, inf, (2,), float64), 'to_target': Box(-inf, inf, (2,), float64), 'velocity': Box(-inf, inf, (2,), float64))
#
# ________________________
#
# BoundedArray(shape=(2,), dtype=dtype('float64'), name=None, minimum=[-1. -1.], maximum=[1. 1.])
#
# Box(-1.0, 1.0, (2,), float64)
#
# OrderedDict([('orientation', Array(shape=(2,), dtype=dtype('float64'), name='orientation')), ('velocity', Array(shape=(1,), dtype=dtype('float64'), name='velocity'))])
#
# Dict('orientation': Box(-inf, inf, (2,), float64), 'velocity': Box(-inf, inf, (1,), float64))
#
# ________________________
#
# BoundedArray(shape=(1,), dtype=dtype('float64'), name=None, minimum=[-1.], maximum=[1.])
#
# Box(-1.0, 1.0, (1,), float64)
